# %%
import os
import numpy as np
import functools
import pandas as pd
from matplotlib import colors
import matplotlib.pyplot as plt
from collections import defaultdict
from utils.manager import UEManager

def b_g(s, A, cmap='PuBu', low=0.8, high=0):
    # Pass the columns from Dataframe A
    i = A.columns.tolist().index(s.name)
    a = A.values[:,i].copy()
    if s.name[-1] in ['rcc-auc']:
        a = -a
    if s.name[0] in ['BARTScoreSeq-rh', 'BARTScoreToken-rh']:
        a = -a
    rng = a.max() - a.min()
    norm = colors.Normalize(a.min() - (rng * low),
                        a.max() + (rng * high))
    normed = norm(a)
    c = [colors.rgb2hex(x) for x in plt.colormaps[cmap](normed)]
    return ['background-color: %s' % color for color in c]

def pretty_est_name(e):
    if e.startswith('AttentionRecursiveSeq_'):
        e = 'Exponential' + e
    if 'Attention' in e or e == 'PUncertainty' or 'AdaptedSampling' in e:
        return e + '*'
    return e

def pretty_gen_metrics_name(g):
    if g == 'WERTokenwise':
        return 'LCS'
    return g

def get_array(dfs, row, col):
    vals = []
    for df in dfs:
        if row in df.index and col in df.columns:
            vals.append(df.loc[row, col])
    return vals

def pretty_plot(dataset_name, man_files, except_metrics=[], except_gen=['BARTScoreSeq-rh'], level='sequence'):
    dfs = []
    if isinstance(dataset_name, str):
        dataset_name = [dataset_name]
        man_files = [man_files]
    columns = []
    for group_name, group_files in zip(dataset_name, man_files):
        gen_metrics = None
        for f in group_files:
            man = UEManager.load(f)
            estimators = [e for (l, e) in man.estimations.keys() if l == level]
            gen_metrics = list(set([(group_name, pretty_gen_metrics_name(gen_name), m_name)
               for (l, e_name, gen_name, m_name) in man.metrics
               if l == level and (m_name not in except_metrics) and (gen_name not in except_gen)]))
            gen_metrics.sort()
            df = {k: {} for k in gen_metrics}
            for (l, e_name, gen_name, m_name), value in man.metrics.items():
                if l == level and (m_name not in except_metrics) and (gen_name not in except_gen):
                    df[group_name, pretty_gen_metrics_name(gen_name), m_name][e_name] = value
            for k in gen_metrics:
                df[k] = [df[k][e] for e in estimators]
            df = pd.DataFrame(data=df, index=[pretty_est_name(e) for e in estimators])
            df = df.reindex(columns=gen_metrics)
            dfs.append(df)
        print('Will measure variance using', len(group_files), 'seeds')
        columns += gen_metrics
    assert(len(dfs) > 0)
    index = dfs[0].index
    mean, total = defaultdict(lambda: defaultdict(int)), defaultdict(lambda: defaultdict(int))
    for col in columns:
        for row in index:
            vals = get_array(dfs, row, col)
            mean[row][col] = -np.mean(vals)
            total[row][col] = '{:.2f} ± {:.2f}'.format(np.mean(vals).item() * 100, np.std(vals).item() * 100)
    
    total_df = pd.DataFrame([[total[row][col] for col in columns] for row in index],
                            index=index, columns=pd.MultiIndex.from_tuples(columns))
    mean_df = pd.DataFrame([[mean[row][col] for col in columns] for row in index],
                           index=index, columns=pd.MultiIndex.from_tuples(columns))
    
    s = total_df.style.apply(functools.partial(b_g, A=mean_df, cmap='Reds'), axis=0)
    s.set_table_styles([{  # for row hover use <tr> instead of <td>
        'selector': 'td:hover',
        'props': [('background-color', '#ffffb3')]
    }, {
        'selector': '.index_name',
        'props': 'font-style: italic; color: darkgrey; font-weight:normal;'
    }])
    s.set_table_styles({
        columns[i]: [{'selector': 'th', 'props': 'border-left: {}px solid black'.format(1 if columns[i][0] == columns[i - 1][0] else 2)},
                     {'selector': 'td', 'props': 'border-left: {}px solid black'.format(1 if columns[i][0] == columns[i - 1][0] else 2)}]
        for i in range(1, len(columns)) if i == 0 or columns[i][1] != columns[i - 1][1]
    }, overwrite=False, axis=0)
    return s

# %%
pretty_plot(
    'TriviaQA, Dolly3b',
    ['/Users/ekaterinafadeeva/work/data/uncertainty_mans/ue_mans/qa_dolly3b_seed' + str(x)
     for x in range(1, 10)])
# Out:
# Will measure variance using 9 seeds
# <style type="text/css">
# #T_028ca_ td:hover {
#   background-color: #ffffb3;
# }
# #T_028ca_ .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_028ca_ th.col3 {
#   border-left: 1px solid black;
# }
# #T_028ca_ td.col3 {
#   border-left: 1px solid black;
# }
# #T_028ca_ th.col6 {
#   border-left: 1px solid black;
# }
# #T_028ca_ td.col6 {
#   border-left: 1px solid black;
# }
# #T_028ca_row0_col0, #T_028ca_row0_col1, #T_028ca_row0_col6, #T_028ca_row0_col7, #T_028ca_row4_col0, #T_028ca_row4_col1, #T_028ca_row4_col6, #T_028ca_row4_col7 {
#   background-color: #b71319;
# }
# #T_028ca_row0_col2, #T_028ca_row0_col8, #T_028ca_row1_col2, #T_028ca_row1_col8, #T_028ca_row4_col2, #T_028ca_row4_col8 {
#   background-color: #f5533b;
# }
# #T_028ca_row0_col3, #T_028ca_row0_col4, #T_028ca_row4_col3, #T_028ca_row4_col4, #T_028ca_row20_col5 {
#   background-color: #b01217;
# }
# #T_028ca_row0_col5, #T_028ca_row4_col5, #T_028ca_row7_col0, #T_028ca_row7_col1, #T_028ca_row7_col6, #T_028ca_row7_col7 {
#   background-color: #dc2924;
# }
# #T_028ca_row1_col0, #T_028ca_row1_col1, #T_028ca_row1_col3, #T_028ca_row1_col4, #T_028ca_row1_col6, #T_028ca_row1_col7, #T_028ca_row11_col2, #T_028ca_row11_col5, #T_028ca_row11_col8 {
#   background-color: #fb7c5c;
# }
# #T_028ca_row1_col5, #T_028ca_row5_col2, #T_028ca_row5_col8, #T_028ca_row7_col5, #T_028ca_row8_col0, #T_028ca_row8_col1, #T_028ca_row8_col6, #T_028ca_row8_col7, #T_028ca_row10_col5 {
#   background-color: #d92523;
# }
# #T_028ca_row2_col0, #T_028ca_row2_col1, #T_028ca_row2_col6, #T_028ca_row2_col7 {
#   background-color: #c3161b;
# }
# #T_028ca_row2_col2, #T_028ca_row2_col8 {
#   background-color: #f6583e;
# }
# #T_028ca_row2_col3, #T_028ca_row2_col4, #T_028ca_row6_col0, #T_028ca_row6_col1, #T_028ca_row6_col6, #T_028ca_row6_col7 {
#   background-color: #bc141a;
# }
# #T_028ca_row2_col5 {
#   background-color: #dd2a25;
# }
# #T_028ca_row3_col0, #T_028ca_row3_col1, #T_028ca_row3_col6, #T_028ca_row3_col7, #T_028ca_row7_col3, #T_028ca_row7_col4 {
#   background-color: #de2b25;
# }
# #T_028ca_row3_col2, #T_028ca_row3_col8 {
#   background-color: #fb6c4c;
# }
# #T_028ca_row3_col3, #T_028ca_row3_col4, #T_028ca_row8_col5 {
#   background-color: #db2824;
# }
# #T_028ca_row3_col5 {
#   background-color: #f24734;
# }
# #T_028ca_row5_col0, #T_028ca_row5_col1, #T_028ca_row5_col6, #T_028ca_row5_col7 {
#   background-color: #b91419;
# }
# #T_028ca_row5_col3, #T_028ca_row5_col4, #T_028ca_row13_col5, #T_028ca_row14_col5 {
#   background-color: #bb141a;
# }
# #T_028ca_row5_col5 {
#   background-color: #a50f15;
# }
# #T_028ca_row6_col2, #T_028ca_row6_col8 {
#   background-color: #e43027;
# }
# #T_028ca_row6_col3, #T_028ca_row6_col4, #T_028ca_row19_col5 {
#   background-color: #b61319;
# }
# #T_028ca_row6_col5 {
#   background-color: #b11218;
# }
# #T_028ca_row7_col2, #T_028ca_row7_col8, #T_028ca_row10_col2, #T_028ca_row10_col8 {
#   background-color: #f5523a;
# }
# #T_028ca_row8_col2, #T_028ca_row8_col8 {
#   background-color: #f6553c;
# }
# #T_028ca_row8_col3, #T_028ca_row8_col4 {
#   background-color: #d52221;
# }
# #T_028ca_row9_col0, #T_028ca_row9_col1, #T_028ca_row9_col6, #T_028ca_row9_col7 {
#   background-color: #d11e1f;
# }
# #T_028ca_row9_col2, #T_028ca_row9_col8 {
#   background-color: #f44d38;
# }
# #T_028ca_row9_col3, #T_028ca_row9_col4, #T_028ca_row10_col3, #T_028ca_row10_col4 {
#   background-color: #cb181d;
# }
# #T_028ca_row9_col5 {
#   background-color: #d72322;
# }
# #T_028ca_row10_col0, #T_028ca_row10_col1, #T_028ca_row10_col6, #T_028ca_row10_col7 {
#   background-color: #d21f20;
# }
# #T_028ca_row11_col0, #T_028ca_row11_col1, #T_028ca_row11_col6, #T_028ca_row11_col7 {
#   background-color: #ac1117;
# }
# #T_028ca_row11_col3, #T_028ca_row11_col4, #T_028ca_row21_col5 {
#   background-color: #a91016;
# }
# #T_028ca_row12_col0, #T_028ca_row12_col1, #T_028ca_row12_col6, #T_028ca_row12_col7 {
#   background-color: #a81016;
# }
# #T_028ca_row12_col2, #T_028ca_row12_col8 {
#   background-color: #fb7353;
# }
# #T_028ca_row12_col3, #T_028ca_row12_col4 {
#   background-color: #ab1016;
# }
# #T_028ca_row12_col5 {
#   background-color: #f75b40;
# }
# #T_028ca_row13_col0, #T_028ca_row13_col1, #T_028ca_row13_col6, #T_028ca_row13_col7, #T_028ca_row14_col0, #T_028ca_row14_col1, #T_028ca_row14_col6, #T_028ca_row14_col7 {
#   background-color: #8c0912;
# }
# #T_028ca_row13_col2, #T_028ca_row13_col8, #T_028ca_row14_col2, #T_028ca_row14_col8 {
#   background-color: #e83429;
# }
# #T_028ca_row13_col3, #T_028ca_row13_col4, #T_028ca_row14_col3, #T_028ca_row14_col4 {
#   background-color: #79040f;
# }
# #T_028ca_row15_col0, #T_028ca_row15_col1, #T_028ca_row15_col3, #T_028ca_row15_col4, #T_028ca_row15_col6, #T_028ca_row15_col7, #T_028ca_row16_col2, #T_028ca_row16_col8 {
#   background-color: #7e0610;
# }
# #T_028ca_row15_col2, #T_028ca_row15_col8 {
#   background-color: #a10e15;
# }
# #T_028ca_row15_col5, #T_028ca_row18_col3, #T_028ca_row18_col4 {
#   background-color: #920a13;
# }
# #T_028ca_row16_col0, #T_028ca_row16_col1, #T_028ca_row16_col6, #T_028ca_row16_col7, #T_028ca_row19_col3, #T_028ca_row19_col4 {
#   background-color: #77040f;
# }
# #T_028ca_row16_col3, #T_028ca_row16_col4, #T_028ca_row20_col3, #T_028ca_row20_col4 {
#   background-color: #73030f;
# }
# #T_028ca_row16_col5 {
#   background-color: #7a0510;
# }
# #T_028ca_row17_col0, #T_028ca_row17_col1, #T_028ca_row17_col2, #T_028ca_row17_col3, #T_028ca_row17_col4, #T_028ca_row17_col5, #T_028ca_row17_col6, #T_028ca_row17_col7, #T_028ca_row17_col8 {
#   background-color: #67000d;
# }
# #T_028ca_row18_col0, #T_028ca_row18_col1, #T_028ca_row18_col6, #T_028ca_row18_col7 {
#   background-color: #9a0c14;
# }
# #T_028ca_row18_col2, #T_028ca_row18_col8 {
#   background-color: #c9181d;
# }
# #T_028ca_row18_col5 {
#   background-color: #c4161c;
# }
# #T_028ca_row19_col0, #T_028ca_row19_col1, #T_028ca_row19_col6, #T_028ca_row19_col7 {
#   background-color: #880811;
# }
# #T_028ca_row19_col2, #T_028ca_row19_col8 {
#   background-color: #e02c26;
# }
# #T_028ca_row20_col0, #T_028ca_row20_col1, #T_028ca_row20_col6, #T_028ca_row20_col7 {
#   background-color: #860811;
# }
# #T_028ca_row20_col2, #T_028ca_row20_col8 {
#   background-color: #e22e27;
# }
# #T_028ca_row21_col0, #T_028ca_row21_col1, #T_028ca_row21_col6, #T_028ca_row21_col7 {
#   background-color: #820711;
# }
# #T_028ca_row21_col2, #T_028ca_row21_col8 {
#   background-color: #da2723;
# }
# #T_028ca_row21_col3, #T_028ca_row21_col4 {
#   background-color: #6d010e;
# }
# </style>
# <table id="T_028ca_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="9">TriviaQA, Dolly3b</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" colspan="3">Rouge_rouge1</th>
#       <th class="col_heading level1 col3" colspan="3">Rouge_rouge2</th>
#       <th class="col_heading level1 col6" colspan="3">Rouge_rougeL</th>
#     </tr>
#     <tr>
#       <th class="blank level2" >&nbsp;</th>
#       <th class="col_heading level2 col0" >prr</th>
#       <th class="col_heading level2 col1" >rcc-auc</th>
#       <th class="col_heading level2 col2" >rpp</th>
#       <th class="col_heading level2 col3" >prr</th>
#       <th class="col_heading level2 col4" >rcc-auc</th>
#       <th class="col_heading level2 col5" >rpp</th>
#       <th class="col_heading level2 col6" >prr</th>
#       <th class="col_heading level2 col7" >rcc-auc</th>
#       <th class="col_heading level2 col8" >rpp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_028ca_level0_row0" class="row_heading level0 row0" >MaxProbabilitySeq</th>
#       <td id="T_028ca_row0_col0" class="data row0 col0" >2.12 ± 0.43</td>
#       <td id="T_028ca_row0_col1" class="data row0 col1" >97.88 ± 0.43</td>
#       <td id="T_028ca_row0_col2" class="data row0 col2" >15.31 ± 0.00</td>
#       <td id="T_028ca_row0_col3" class="data row0 col3" >1.93 ± 0.50</td>
#       <td id="T_028ca_row0_col4" class="data row0 col4" >98.07 ± 0.50</td>
#       <td id="T_028ca_row0_col5" class="data row0 col5" >9.18 ± 0.00</td>
#       <td id="T_028ca_row0_col6" class="data row0 col6" >2.12 ± 0.43</td>
#       <td id="T_028ca_row0_col7" class="data row0 col7" >97.88 ± 0.43</td>
#       <td id="T_028ca_row0_col8" class="data row0 col8" >15.31 ± 0.00</td>
#     </tr>
#     <tr>
#       <t

# %%
pretty_plot(
    'TriviaQA, Bloomz3b',
    ['/Users/ekaterinafadeeva/work/data/uncertainty_mans/ue_mans/qa_bloomz3b_seed' + str(x)
     for x in range(1, 10)])
# Out:
# Will measure variance using 9 seeds
# <style type="text/css">
# #T_a244d_ td:hover {
#   background-color: #ffffb3;
# }
# #T_a244d_ .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_a244d_ th.col3 {
#   border-left: 1px solid black;
# }
# #T_a244d_ td.col3 {
#   border-left: 1px solid black;
# }
# #T_a244d_ th.col6 {
#   border-left: 1px solid black;
# }
# #T_a244d_ td.col6 {
#   border-left: 1px solid black;
# }
# #T_a244d_row0_col0, #T_a244d_row0_col1, #T_a244d_row0_col2, #T_a244d_row0_col3, #T_a244d_row0_col5, #T_a244d_row0_col6, #T_a244d_row0_col7, #T_a244d_row0_col8, #T_a244d_row4_col0, #T_a244d_row4_col1, #T_a244d_row4_col2, #T_a244d_row4_col3, #T_a244d_row4_col5, #T_a244d_row4_col6, #T_a244d_row4_col7, #T_a244d_row4_col8, #T_a244d_row16_col4 {
#   background-color: #67000d;
# }
# #T_a244d_row0_col4, #T_a244d_row1_col3, #T_a244d_row2_col3, #T_a244d_row4_col4, #T_a244d_row5_col2, #T_a244d_row5_col5, #T_a244d_row5_col8, #T_a244d_row6_col2, #T_a244d_row6_col8, #T_a244d_row7_col2, #T_a244d_row7_col8, #T_a244d_row8_col2, #T_a244d_row8_col8, #T_a244d_row10_col5 {
#   background-color: #6d010e;
# }
# #T_a244d_row1_col0, #T_a244d_row1_col1, #T_a244d_row1_col6, #T_a244d_row1_col7, #T_a244d_row5_col0, #T_a244d_row5_col1, #T_a244d_row5_col6, #T_a244d_row5_col7, #T_a244d_row7_col0, #T_a244d_row7_col1, #T_a244d_row7_col6, #T_a244d_row7_col7, #T_a244d_row8_col0, #T_a244d_row8_col1, #T_a244d_row8_col6, #T_a244d_row8_col7 {
#   background-color: #75030f;
# }
# #T_a244d_row1_col2, #T_a244d_row1_col8, #T_a244d_row2_col2, #T_a244d_row2_col8, #T_a244d_row8_col3, #T_a244d_row9_col2, #T_a244d_row9_col8, #T_a244d_row10_col2, #T_a244d_row10_col8, #T_a244d_row15_col2, #T_a244d_row15_col8, #T_a244d_row17_col2, #T_a244d_row17_col8 {
#   background-color: #71020e;
# }
# #T_a244d_row1_col4, #T_a244d_row2_col4, #T_a244d_row6_col0, #T_a244d_row6_col1, #T_a244d_row6_col3, #T_a244d_row6_col6, #T_a244d_row6_col7 {
#   background-color: #77040f;
# }
# #T_a244d_row1_col5, #T_a244d_row7_col3, #T_a244d_row9_col5 {
#   background-color: #6f020e;
# }
# #T_a244d_row2_col0, #T_a244d_row2_col1, #T_a244d_row2_col6, #T_a244d_row2_col7, #T_a244d_row7_col4, #T_a244d_row9_col0, #T_a244d_row9_col1, #T_a244d_row9_col3, #T_a244d_row9_col6, #T_a244d_row9_col7, #T_a244d_row10_col0, #T_a244d_row10_col1, #T_a244d_row10_col3, #T_a244d_row10_col6, #T_a244d_row10_col7, #T_a244d_row16_col5 {
#   background-color: #79040f;
# }
# #T_a244d_row2_col5, #T_a244d_row6_col5, #T_a244d_row7_col5, #T_a244d_row8_col5 {
#   background-color: #6b010e;
# }
# #T_a244d_row3_col0, #T_a244d_row3_col1, #T_a244d_row3_col6, #T_a244d_row3_col7 {
#   background-color: #c9181d;
# }
# #T_a244d_row3_col2, #T_a244d_row3_col8, #T_a244d_row13_col3, #T_a244d_row14_col3 {
#   background-color: #ab1016;
# }
# #T_a244d_row3_col3 {
#   background-color: #e12d26;
# }
# #T_a244d_row3_col4 {
#   background-color: #f34935;
# }
# #T_a244d_row3_col5, #T_a244d_row13_col4, #T_a244d_row14_col4 {
#   background-color: #b91419;
# }
# #T_a244d_row5_col3 {
#   background-color: #73030f;
# }
# #T_a244d_row5_col4, #T_a244d_row16_col3 {
#   background-color: #7e0610;
# }
# #T_a244d_row6_col4 {
#   background-color: #800610;
# }
# #T_a244d_row8_col4 {
#   background-color: #7a0510;
# }
# #T_a244d_row9_col4, #T_a244d_row17_col5 {
#   background-color: #860811;
# }
# #T_a244d_row10_col4, #T_a244d_row15_col0, #T_a244d_row15_col6, #T_a244d_row17_col0, #T_a244d_row17_col6 {
#   background-color: #840711;
# }
# #T_a244d_row11_col0, #T_a244d_row11_col1, #T_a244d_row11_col6, #T_a244d_row11_col7 {
#   background-color: #c4161c;
# }
# #T_a244d_row11_col2, #T_a244d_row11_col8, #T_a244d_row20_col3, #T_a244d_row21_col3 {
#   background-color: #a10e15;
# }
# #T_a244d_row11_col3 {
#   background-color: #bf151b;
# }
# #T_a244d_row11_col4 {
#   background-color: #d11e1f;
# }
# #T_a244d_row11_col5 {
#   background-color: #9d0d14;
# }
# #T_a244d_row12_col0, #T_a244d_row12_col1, #T_a244d_row12_col4, #T_a244d_row12_col6, #T_a244d_row12_col7, #T_a244d_row18_col2, #T_a244d_row18_col3, #T_a244d_row18_col5, #T_a244d_row18_col8 {
#   background-color: #fb7c5c;
# }
# #T_a244d_row12_col2, #T_a244d_row12_col8 {
#   background-color: #c8171c;
# }
# #T_a244d_row12_col3 {
#   background-color: #f6553c;
# }
# #T_a244d_row12_col5 {
#   background-color: #c1161b;
# }
# #T_a244d_row13_col0, #T_a244d_row13_col1, #T_a244d_row14_col0, #T_a244d_row14_col1, #T_a244d_row21_col4 {
#   background-color: #af1117;
# }
# #T_a244d_row13_col2, #T_a244d_row13_col8, #T_a244d_row14_col2, #T_a244d_row14_col8 {
#   background-color: #940b13;
# }
# #T_a244d_row13_col5, #T_a244d_row14_col5, #T_a244d_row20_col2, #T_a244d_row20_col8 {
#   background-color: #900a12;
# }
# #T_a244d_row13_col6, #T_a244d_row13_col7, #T_a244d_row14_col6, #T_a244d_row14_col7 {
#   background-color: #ad1117;
# }
# #T_a244d_row15_col1, #T_a244d_row15_col7, #T_a244d_row17_col1, #T_a244d_row17_col7 {
#   background-color: #820711;
# }
# #T_a244d_row15_col3, #T_a244d_row17_col3 {
#   background-color: #a50f15;
# }
# #T_a244d_row15_col4, #T_a244d_row17_col4 {
#   background-color: #b21218;
# }
# #T_a244d_row15_col5 {
#   background-color: #880811;
# }
# #T_a244d_row16_col0, #T_a244d_row16_col6 {
#   background-color: #e43027;
# }
# #T_a244d_row16_col1, #T_a244d_row16_col7 {
#   background-color: #ce1a1e;
# }
# #T_a244d_row16_col2, #T_a244d_row16_col8 {
#   background-color: #ca181d;
# }
# #T_a244d_row18_col0, #T_a244d_row18_col6 {
#   background-color: #fb6e4e;
# }
# #T_a244d_row18_col1, #T_a244d_row18_col7 {
#   background-color: #d01d1f;
# }
# #T_a244d_row18_col4 {
#   background-color: #d72322;
# }
# #T_a244d_row19_col0, #T_a244d_row19_col1, #T_a244d_row19_col3, #T_a244d_row19_col6, #T_a244d_row19_col7, #T_a244d_row20_col6, #T_a244d_row20_col7 {
#   background-color: #a91016;
# }
# #T_a244d_row19_col2, #T_a244d_row19_col5, #T_a244d_row19_col8, #T_a244d_row21_col2, #T_a244d_row21_col8 {
#   background-color: #8e0912;
# }
# #T_a244d_row19_col4 {
#   background-color: #b61319;
# }
# #T_a244d_row20_col0, #T_a244d_row20_col1 {
#   background-color: #aa1016;
# }
# #T_a244d_row20_col4 {
#   background-color: #b01217;
# }
# #T_a244d_row20_col5, #T_a244d_row21_col5 {
#   background-color: #8a0812;
# }
# #T_a244d_row21_col0, #T_a244d_row21_col1, #T_a244d_row21_col6, #T_a244d_row21_col7 {
#   background-color: #a60f15;
# }
# </style>
# <table id="T_a244d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="9">TriviaQA, Bloomz3b</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" colspan="3">Rouge_rouge1</th>
#       <th class="col_heading level1 col3" colspan="3">Rouge_rouge2</th>
#       <th class="col_heading level1 col6" colspan="3">Rouge_rougeL</th>
#     </tr>
#     <tr>
#       <th class="blank level2" >&nbsp;</th>
#       <th class="col_heading level2 col0" >prr</th>
#       <th class="col_heading level2 col1" >rcc-auc</th>
#       <th class="col_heading level2 col2" >rpp</th>
#       <th class="col_heading level2 col3" >prr</th>
#       <th class="col_heading level2 col4" >rcc-auc</th>
#       <th class="col_heading level2 col5" >rpp</th>
#       <th class="col_heading level2 col6" >prr</th>
#       <th class="col_heading level2 col7" >rcc-auc</th>
#       <th class="col_heading level2 col8" >rpp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a244d_level0_row0" class="row_heading level0 row0" >MaxProbabilitySeq</th>
#       <td id="T_a244d_row0_col0" class="data row0 col0" >12.63 ± 0.00</td>
#       <td id="T_a244d_row0_col1" class="data row0 col1" >87.37 ± 0.00</td>
#       <td id="T_a244d_row0_col2" class="data row0 col2" >6.49 ± 0.00</td>
#       <td id="T_a244d_row0_col3" class="data row0 col3" >6.61 ± 0.00</td>
#       <td id="T_a244d_row0_col4" class="data row0 col4" >93.39 ± 0.00</td>
#       <td id="T_a244d_row0_col5" class="data row0 col5" >3.14 ± 0.00</td>
#       <td id="T_a244d_row0_col6" class="data row0 col6" >12.61 ± 0.00</td>
#       <td id="T_a244d_row0_col7" class="data row0 col7" >87.39 ± 0.00</td>
#       <td id="T_a244d_row0_col8" class="data row0 col8" >6.54 ± 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_a244d_level0_row1" class="row_heading level0 row1" >MaxProbabilityNormalizedSeq</th>
#       <td id="T_a244d_row1_col0" class="data row1 col0" >13.83 ± 0

# %%
pretty_plot(
    'XSUM, Dolly3b',
    ['/Users/ekaterinafadeeva/work/data/uncertainty_mans/ue_mans/xsum_dolly3b_seed' + str(x)
     for x in range(1, 6)])
# Out:
# Will measure variance using 5 seeds
# <style type="text/css">
# #T_a5e2d_ td:hover {
#   background-color: #ffffb3;
# }
# #T_a5e2d_ .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_a5e2d_ th.col3 {
#   border-left: 1px solid black;
# }
# #T_a5e2d_ td.col3 {
#   border-left: 1px solid black;
# }
# #T_a5e2d_ th.col6 {
#   border-left: 1px solid black;
# }
# #T_a5e2d_ td.col6 {
#   border-left: 1px solid black;
# }
# #T_a5e2d_row0_col0, #T_a5e2d_row0_col1, #T_a5e2d_row4_col0, #T_a5e2d_row4_col1, #T_a5e2d_row12_col5 {
#   background-color: #ee3a2c;
# }
# #T_a5e2d_row0_col2, #T_a5e2d_row4_col2 {
#   background-color: #e43027;
# }
# #T_a5e2d_row0_col3, #T_a5e2d_row0_col4, #T_a5e2d_row4_col3, #T_a5e2d_row4_col4 {
#   background-color: #bc141a;
# }
# #T_a5e2d_row0_col5, #T_a5e2d_row4_col5, #T_a5e2d_row17_col5 {
#   background-color: #e12d26;
# }
# #T_a5e2d_row0_col6, #T_a5e2d_row0_col7, #T_a5e2d_row4_col6, #T_a5e2d_row4_col7, #T_a5e2d_row8_col8 {
#   background-color: #ce1a1e;
# }
# #T_a5e2d_row0_col8, #T_a5e2d_row4_col8, #T_a5e2d_row9_col2, #T_a5e2d_row16_col3, #T_a5e2d_row16_col4 {
#   background-color: #d82422;
# }
# #T_a5e2d_row1_col0, #T_a5e2d_row1_col1, #T_a5e2d_row3_col6, #T_a5e2d_row3_col7 {
#   background-color: #f44f39;
# }
# #T_a5e2d_row1_col2 {
#   background-color: #eb372a;
# }
# #T_a5e2d_row1_col3, #T_a5e2d_row1_col4, #T_a5e2d_row6_col2, #T_a5e2d_row9_col5 {
#   background-color: #d21f20;
# }
# #T_a5e2d_row1_col5, #T_a5e2d_row6_col0, #T_a5e2d_row6_col1, #T_a5e2d_row12_col3, #T_a5e2d_row12_col4 {
#   background-color: #e22e27;
# }
# #T_a5e2d_row1_col6, #T_a5e2d_row1_col7, #T_a5e2d_row2_col2, #T_a5e2d_row8_col2 {
#   background-color: #dd2a25;
# }
# #T_a5e2d_row1_col8, #T_a5e2d_row5_col0, #T_a5e2d_row5_col1 {
#   background-color: #de2b25;
# }
# #T_a5e2d_row2_col0, #T_a5e2d_row2_col1, #T_a5e2d_row7_col0, #T_a5e2d_row7_col1, #T_a5e2d_row8_col0, #T_a5e2d_row8_col1, #T_a5e2d_row10_col0, #T_a5e2d_row10_col1 {
#   background-color: #ea362a;
# }
# #T_a5e2d_row2_col3, #T_a5e2d_row2_col4, #T_a5e2d_row7_col3, #T_a5e2d_row7_col4, #T_a5e2d_row9_col3, #T_a5e2d_row9_col4, #T_a5e2d_row12_col0, #T_a5e2d_row12_col1 {
#   background-color: #b71319;
# }
# #T_a5e2d_row2_col5, #T_a5e2d_row8_col5 {
#   background-color: #d92523;
# }
# #T_a5e2d_row2_col6, #T_a5e2d_row2_col7, #T_a5e2d_row5_col8 {
#   background-color: #c1161b;
# }
# #T_a5e2d_row2_col8, #T_a5e2d_row5_col5 {
#   background-color: #cc191e;
# }
# #T_a5e2d_row3_col0, #T_a5e2d_row3_col1 {
#   background-color: #fb7151;
# }
# #T_a5e2d_row3_col2, #T_a5e2d_row3_col5, #T_a5e2d_row3_col8, #T_a5e2d_row11_col0, #T_a5e2d_row11_col1, #T_a5e2d_row15_col3, #T_a5e2d_row15_col4, #T_a5e2d_row15_col6, #T_a5e2d_row15_col7 {
#   background-color: #fb7c5c;
# }
# #T_a5e2d_row3_col3, #T_a5e2d_row3_col4 {
#   background-color: #fb7757;
# }
# #T_a5e2d_row5_col2, #T_a5e2d_row16_col0, #T_a5e2d_row16_col1 {
#   background-color: #d01d1f;
# }
# #T_a5e2d_row5_col3, #T_a5e2d_row5_col4 {
#   background-color: #af1117;
# }
# #T_a5e2d_row5_col6, #T_a5e2d_row5_col7 {
#   background-color: #b51318;
# }
# #T_a5e2d_row6_col3, #T_a5e2d_row6_col4, #T_a5e2d_row16_col5 {
#   background-color: #b21218;
# }
# #T_a5e2d_row6_col5 {
#   background-color: #cf1c1f;
# }
# #T_a5e2d_row6_col6, #T_a5e2d_row6_col7, #T_a5e2d_row8_col3, #T_a5e2d_row8_col4 {
#   background-color: #b91419;
# }
# #T_a5e2d_row6_col8 {
#   background-color: #c4161c;
# }
# #T_a5e2d_row7_col2, #T_a5e2d_row10_col2 {
#   background-color: #db2824;
# }
# #T_a5e2d_row7_col5, #T_a5e2d_row17_col2 {
#   background-color: #d52221;
# }
# #T_a5e2d_row7_col6, #T_a5e2d_row7_col7, #T_a5e2d_row8_col6, #T_a5e2d_row8_col7, #T_a5e2d_row10_col6, #T_a5e2d_row10_col7 {
#   background-color: #c2161b;
# }
# #T_a5e2d_row7_col8, #T_a5e2d_row10_col8 {
#   background-color: #cb181d;
# }
# #T_a5e2d_row9_col0, #T_a5e2d_row9_col1, #T_a5e2d_row15_col2 {
#   background-color: #e83429;
# }
# #T_a5e2d_row9_col6, #T_a5e2d_row9_col7 {
#   background-color: #bf151b;
# }
# #T_a5e2d_row9_col8 {
#   background-color: #c9181d;
# }
# #T_a5e2d_row10_col3, #T_a5e2d_row10_col4 {
#   background-color: #b81419;
# }
# #T_a5e2d_row10_col5 {
#   background-color: #d72322;
# }
# #T_a5e2d_row11_col2 {
#   background-color: #f14432;
# }
# #T_a5e2d_row11_col3, #T_a5e2d_row11_col4 {
#   background-color: #fb6d4d;
# }
# #T_a5e2d_row11_col5 {
#   background-color: #f6583e;
# }
# #T_a5e2d_row11_col6, #T_a5e2d_row11_col7 {
#   background-color: #f7593f;
# }
# #T_a5e2d_row11_col8 {
#   background-color: #f96346;
# }
# #T_a5e2d_row12_col2 {
#   background-color: #c8171c;
# }
# #T_a5e2d_row12_col6, #T_a5e2d_row12_col7 {
#   background-color: #c7171c;
# }
# #T_a5e2d_row12_col8 {
#   background-color: #f5523a;
# }
# #T_a5e2d_row13_col0, #T_a5e2d_row13_col1, #T_a5e2d_row13_col3, #T_a5e2d_row13_col4, #T_a5e2d_row14_col0, #T_a5e2d_row14_col1, #T_a5e2d_row14_col3, #T_a5e2d_row14_col4, #T_a5e2d_row19_col0, #T_a5e2d_row19_col1, #T_a5e2d_row19_col2, #T_a5e2d_row19_col3, #T_a5e2d_row19_col4, #T_a5e2d_row19_col6, #T_a5e2d_row19_col7, #T_a5e2d_row20_col2, #T_a5e2d_row20_col3, #T_a5e2d_row20_col4, #T_a5e2d_row20_col5, #T_a5e2d_row21_col2, #T_a5e2d_row21_col3, #T_a5e2d_row21_col4, #T_a5e2d_row21_col5, #T_a5e2d_row21_col8 {
#   background-color: #67000d;
# }
# #T_a5e2d_row13_col2, #T_a5e2d_row13_col6, #T_a5e2d_row13_col7, #T_a5e2d_row14_col2, #T_a5e2d_row14_col6, #T_a5e2d_row14_col7, #T_a5e2d_row20_col8 {
#   background-color: #69000d;
# }
# #T_a5e2d_row13_col5, #T_a5e2d_row14_col5, #T_a5e2d_row21_col6, #T_a5e2d_row21_col7 {
#   background-color: #6d010e;
# }
# #T_a5e2d_row13_col8, #T_a5e2d_row14_col8 {
#   background-color: #77040f;
# }
# #T_a5e2d_row15_col0, #T_a5e2d_row15_col1 {
#   background-color: #fb7b5b;
# }
# #T_a5e2d_row15_col5 {
#   background-color: #f03f2e;
# }
# #T_a5e2d_row15_col8 {
#   background-color: #f75c41;
# }
# #T_a5e2d_row16_col2 {
#   background-color: #ad1117;
# }
# #T_a5e2d_row16_col6, #T_a5e2d_row16_col7 {
#   background-color: #d32020;
# }
# #T_a5e2d_row16_col8 {
#   background-color: #be151a;
# }
# #T_a5e2d_row17_col0, #T_a5e2d_row17_col1 {
#   background-color: #fa6849;
# }
# #T_a5e2d_row17_col3, #T_a5e2d_row17_col4 {
#   background-color: #fb7252;
# }
# #T_a5e2d_row17_col6, #T_a5e2d_row17_col7 {
#   background-color: #fb6c4c;
# }
# #T_a5e2d_row17_col8 {
#   background-color: #ed392b;
# }
# #T_a5e2d_row18_col0 {
#   background-color: #9f0e14;
# }
# #T_a5e2d_row18_col1, #T_a5e2d_row18_col3 {
#   background-color: #9d0d14;
# }
# #T_a5e2d_row18_col2 {
#   background-color: #980c13;
# }
# #T_a5e2d_row18_col4 {
#   background-color: #9c0d14;
# }
# #T_a5e2d_row18_col5 {
#   background-color: #a30f15;
# }
# #T_a5e2d_row18_col6 {
#   background-color: #a60f15;
# }
# #T_a5e2d_row18_col7 {
#   background-color: #a50f15;
# }
# #T_a5e2d_row18_col8 {
#   background-color: #a81016;
# }
# #T_a5e2d_row19_col5 {
#   background-color: #6b010e;
# }
# #T_a5e2d_row19_col8, #T_a5e2d_row21_col0, #T_a5e2d_row21_col1 {
#   background-color: #71020e;
# }
# #T_a5e2d_row20_col0, #T_a5e2d_row20_col1 {
#   background-color: #73030f;
# }
# #T_a5e2d_row20_col6, #T_a5e2d_row20_col7 {
#   background-color: #6f020e;
# }
# </style>
# <table id="T_a5e2d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="9">XSUM, Dolly3b</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" colspan="3">Rouge_rouge1</th>
#       <th class="col_heading level1 col3" colspan="3">Rouge_rouge2</th>
#       <th class="col_heading level1 col6" colspan="3">Rouge_rougeL</th>
#     </tr>
#     <tr>
#       <th class="blank level2" >&nbsp;</th>
#       <th class="col_heading level2 col0" >prr</th>
#       <th class="col_heading level2 col1" >rcc-auc</th>
#       <th class="col_heading level2 col2" >rpp</th>
#       <th class="col_heading level2 col3" >prr</th>
#       <th class="col_heading level2 col4" >rcc-auc</th>
#       <th class="col_heading level2 col5" >rpp</th>
#       <th class="col_heading level2 col6" >prr</th>
#       <th class="col_heading level2 col7" >rcc-auc</th>
#       <th class="col_heading level2 col8" >rpp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5e2d_level0_row0" class="row_heading level0 row0" >MaxProbabilitySeq</th>
#       <td id="T_a5e2d_row0_col0" class="data row0 col0" >34.94 ± 0.00</td>
#       <td id="T_a5e2d_row0_col1" class="data row0 col1" >65.06 ± 0.00</td>
#       <td id="T_a5e2d_row0_col2" class="

# %%
pretty_plot(
    'XSUM, Dolly7b',
    ['/Users/ekaterinafadeeva/work/data/uncertainty_mans/ue_mans/xsum_dolly7b_seed' + str(x)
     for x in range(1, 6)])
# Out:
# Will measure variance using 5 seeds
# <style type="text/css">
# #T_c7e86_ td:hover {
#   background-color: #ffffb3;
# }
# #T_c7e86_ .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_c7e86_ th.col3 {
#   border-left: 1px solid black;
# }
# #T_c7e86_ td.col3 {
#   border-left: 1px solid black;
# }
# #T_c7e86_ th.col6 {
#   border-left: 1px solid black;
# }
# #T_c7e86_ td.col6 {
#   border-left: 1px solid black;
# }
# #T_c7e86_row0_col0, #T_c7e86_row0_col1, #T_c7e86_row4_col0, #T_c7e86_row4_col1 {
#   background-color: #c8171c;
# }
# #T_c7e86_row0_col2, #T_c7e86_row4_col2, #T_c7e86_row8_col5 {
#   background-color: #b81419;
# }
# #T_c7e86_row0_col3, #T_c7e86_row0_col4, #T_c7e86_row4_col3, #T_c7e86_row4_col4 {
#   background-color: #b21218;
# }
# #T_c7e86_row0_col5, #T_c7e86_row4_col5 {
#   background-color: #be151a;
# }
# #T_c7e86_row0_col6, #T_c7e86_row0_col7, #T_c7e86_row4_col6, #T_c7e86_row4_col7 {
#   background-color: #7e0610;
# }
# #T_c7e86_row0_col8, #T_c7e86_row2_col6, #T_c7e86_row2_col7, #T_c7e86_row4_col8, #T_c7e86_row10_col6, #T_c7e86_row10_col7, #T_c7e86_row13_col2, #T_c7e86_row13_col3, #T_c7e86_row13_col4, #T_c7e86_row14_col2, #T_c7e86_row14_col3, #T_c7e86_row14_col4, #T_c7e86_row21_col8 {
#   background-color: #79040f;
# }
# #T_c7e86_row1_col0, #T_c7e86_row1_col1 {
#   background-color: #bd151a;
# }
# #T_c7e86_row1_col2, #T_c7e86_row7_col5 {
#   background-color: #b71319;
# }
# #T_c7e86_row1_col3, #T_c7e86_row1_col4 {
#   background-color: #a50f15;
# }
# #T_c7e86_row1_col5, #T_c7e86_row2_col5, #T_c7e86_row5_col0, #T_c7e86_row5_col1 {
#   background-color: #bb141a;
# }
# #T_c7e86_row1_col6, #T_c7e86_row1_col7 {
#   background-color: #880811;
# }
# #T_c7e86_row1_col8, #T_c7e86_row7_col6, #T_c7e86_row7_col7, #T_c7e86_row8_col6, #T_c7e86_row8_col7, #T_c7e86_row19_col3, #T_c7e86_row19_col4, #T_c7e86_row20_col8 {
#   background-color: #77040f;
# }
# #T_c7e86_row2_col0, #T_c7e86_row2_col1, #T_c7e86_row10_col0, #T_c7e86_row10_col1, #T_c7e86_row16_col6, #T_c7e86_row16_col7 {
#   background-color: #c2161b;
# }
# #T_c7e86_row2_col2, #T_c7e86_row6_col5, #T_c7e86_row10_col3, #T_c7e86_row10_col4 {
#   background-color: #b01217;
# }
# #T_c7e86_row2_col3, #T_c7e86_row2_col4, #T_c7e86_row9_col2, #T_c7e86_row10_col2 {
#   background-color: #b11218;
# }
# #T_c7e86_row2_col8, #T_c7e86_row10_col8, #T_c7e86_row19_col6, #T_c7e86_row19_col7 {
#   background-color: #71020e;
# }
# #T_c7e86_row3_col0, #T_c7e86_row3_col1, #T_c7e86_row17_col0, #T_c7e86_row17_col1 {
#   background-color: #f14331;
# }
# #T_c7e86_row3_col2 {
#   background-color: #f85d42;
# }
# #T_c7e86_row3_col3, #T_c7e86_row3_col4 {
#   background-color: #ed392b;
# }
# #T_c7e86_row3_col5 {
#   background-color: #fa6547;
# }
# #T_c7e86_row3_col6, #T_c7e86_row3_col7 {
#   background-color: #d32020;
# }
# #T_c7e86_row3_col8 {
#   background-color: #d52221;
# }
# #T_c7e86_row5_col2 {
#   background-color: #a91016;
# }
# #T_c7e86_row5_col3, #T_c7e86_row5_col4, #T_c7e86_row16_col5, #T_c7e86_row16_col8 {
#   background-color: #a30f15;
# }
# #T_c7e86_row5_col5, #T_c7e86_row7_col3, #T_c7e86_row7_col4 {
#   background-color: #ad1117;
# }
# #T_c7e86_row5_col6, #T_c7e86_row5_col7, #T_c7e86_row6_col6, #T_c7e86_row6_col7, #T_c7e86_row13_col6, #T_c7e86_row13_col7, #T_c7e86_row14_col6, #T_c7e86_row14_col7 {
#   background-color: #73030f;
# }
# #T_c7e86_row5_col8, #T_c7e86_row20_col0, #T_c7e86_row20_col1, #T_c7e86_row20_col2, #T_c7e86_row20_col3, #T_c7e86_row20_col4, #T_c7e86_row20_col5, #T_c7e86_row20_col6, #T_c7e86_row20_col7 {
#   background-color: #67000d;
# }
# #T_c7e86_row6_col0, #T_c7e86_row6_col1 {
#   background-color: #bc141a;
# }
# #T_c7e86_row6_col2 {
#   background-color: #ab1016;
# }
# #T_c7e86_row6_col3, #T_c7e86_row6_col4, #T_c7e86_row18_col6 {
#   background-color: #a60f15;
# }
# #T_c7e86_row6_col8, #T_c7e86_row21_col6, #T_c7e86_row21_col7 {
#   background-color: #69000d;
# }
# #T_c7e86_row7_col0, #T_c7e86_row7_col1, #T_c7e86_row8_col0, #T_c7e86_row8_col1 {
#   background-color: #c1161b;
# }
# #T_c7e86_row7_col2, #T_c7e86_row8_col2, #T_c7e86_row8_col3, #T_c7e86_row8_col4 {
#   background-color: #af1117;
# }
# #T_c7e86_row7_col8, #T_c7e86_row8_col8, #T_c7e86_row9_col8, #T_c7e86_row21_col5 {
#   background-color: #6f020e;
# }
# #T_c7e86_row9_col0, #T_c7e86_row9_col1 {
#   background-color: #bf151b;
# }
# #T_c7e86_row9_col3, #T_c7e86_row9_col4 {
#   background-color: #ac1117;
# }
# #T_c7e86_row9_col5 {
#   background-color: #b61319;
# }
# #T_c7e86_row9_col6, #T_c7e86_row9_col7 {
#   background-color: #75030f;
# }
# #T_c7e86_row10_col5, #T_c7e86_row16_col2, #T_c7e86_row18_col4 {
#   background-color: #b91419;
# }
# #T_c7e86_row11_col0, #T_c7e86_row11_col1, #T_c7e86_row11_col2, #T_c7e86_row11_col5, #T_c7e86_row11_col6, #T_c7e86_row11_col7, #T_c7e86_row11_col8, #T_c7e86_row15_col3, #T_c7e86_row15_col4 {
#   background-color: #fb7c5c;
# }
# #T_c7e86_row11_col3, #T_c7e86_row11_col4 {
#   background-color: #fb7858;
# }
# #T_c7e86_row12_col0, #T_c7e86_row12_col1 {
#   background-color: #ee3a2c;
# }
# #T_c7e86_row12_col2 {
#   background-color: #f34c37;
# }
# #T_c7e86_row12_col3, #T_c7e86_row12_col4 {
#   background-color: #fb7757;
# }
# #T_c7e86_row12_col5 {
#   background-color: #fb6c4c;
# }
# #T_c7e86_row12_col6, #T_c7e86_row12_col7 {
#   background-color: #f4503a;
# }
# #T_c7e86_row12_col8, #T_c7e86_row17_col3, #T_c7e86_row17_col4 {
#   background-color: #fb6d4d;
# }
# #T_c7e86_row13_col0, #T_c7e86_row13_col1, #T_c7e86_row14_col0, #T_c7e86_row14_col1, #T_c7e86_row18_col8, #T_c7e86_row19_col0, #T_c7e86_row19_col1, #T_c7e86_row19_col5 {
#   background-color: #820711;
# }
# #T_c7e86_row13_col5, #T_c7e86_row13_col8, #T_c7e86_row14_col5, #T_c7e86_row14_col8 {
#   background-color: #800610;
# }
# #T_c7e86_row15_col0, #T_c7e86_row15_col1 {
#   background-color: #f5523a;
# }
# #T_c7e86_row15_col2, #T_c7e86_row17_col6, #T_c7e86_row17_col7 {
#   background-color: #f0402f;
# }
# #T_c7e86_row15_col5 {
#   background-color: #ec382b;
# }
# #T_c7e86_row15_col6, #T_c7e86_row15_col7 {
#   background-color: #f75b40;
# }
# #T_c7e86_row15_col8 {
#   background-color: #e53228;
# }
# #T_c7e86_row16_col0, #T_c7e86_row16_col1, #T_c7e86_row17_col8 {
#   background-color: #cb181d;
# }
# #T_c7e86_row16_col3, #T_c7e86_row16_col4 {
#   background-color: #d92523;
# }
# #T_c7e86_row17_col2 {
#   background-color: #e12d26;
# }
# #T_c7e86_row17_col5 {
#   background-color: #da2723;
# }
# #T_c7e86_row18_col0 {
#   background-color: #b51318;
# }
# #T_c7e86_row18_col1, #T_c7e86_row18_col5 {
#   background-color: #aa1016;
# }
# #T_c7e86_row18_col2 {
#   background-color: #960b13;
# }
# #T_c7e86_row18_col3 {
#   background-color: #c4161c;
# }
# #T_c7e86_row18_col7 {
#   background-color: #940b13;
# }
# #T_c7e86_row19_col2, #T_c7e86_row19_col8 {
#   background-color: #7c0510;
# }
# #T_c7e86_row21_col0, #T_c7e86_row21_col1, #T_c7e86_row21_col2, #T_c7e86_row21_col3, #T_c7e86_row21_col4 {
#   background-color: #6d010e;
# }
# </style>
# <table id="T_c7e86_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="9">XSUM, Dolly7b</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" colspan="3">Rouge_rouge1</th>
#       <th class="col_heading level1 col3" colspan="3">Rouge_rouge2</th>
#       <th class="col_heading level1 col6" colspan="3">Rouge_rougeL</th>
#     </tr>
#     <tr>
#       <th class="blank level2" >&nbsp;</th>
#       <th class="col_heading level2 col0" >prr</th>
#       <th class="col_heading level2 col1" >rcc-auc</th>
#       <th class="col_heading level2 col2" >rpp</th>
#       <th class="col_heading level2 col3" >prr</th>
#       <th class="col_heading level2 col4" >rcc-auc</th>
#       <th class="col_heading level2 col5" >rpp</th>
#       <th class="col_heading level2 col6" >prr</th>
#       <th class="col_heading level2 col7" >rcc-auc</th>
#       <th class="col_heading level2 col8" >rpp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7e86_level0_row0" class="row_heading level0 row0" >MaxProbabilitySeq</th>
#       <td id="T_c7e86_row0_col0" class="data row0 col0" >15.54 ± 9.75</td>
#       <td id="T_c7e86_row0_col1" class="data row0 col1" >84.46 ± 9.75</td>
#       <td id="T_c7e86_row0_col2" class="data row0 col2" >22.89 ± 0.00</td>
#       <td id="T_c7e86_row0_col3" class="data row0 col3" >3.79 ± 3.95</td>
#       <td id="T_c7e86_row0_col4" class="data row0 c

# %%
pretty_plot(
    'XSUM, bloomz3b',
    ['/Users/ekaterinafadeeva/work/data/uncertainty_mans/ue_mans/xsum_bloomz3b_seed' + str(x)
     for x in range(1, 10)])
# Out:
# Will measure variance using 9 seeds
# <style type="text/css">
# #T_01e52_ td:hover {
#   background-color: #ffffb3;
# }
# #T_01e52_ .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_01e52_ th.col3 {
#   border-left: 1px solid black;
# }
# #T_01e52_ td.col3 {
#   border-left: 1px solid black;
# }
# #T_01e52_ th.col6 {
#   border-left: 1px solid black;
# }
# #T_01e52_ td.col6 {
#   border-left: 1px solid black;
# }
# #T_01e52_row0_col0, #T_01e52_row0_col1, #T_01e52_row4_col0, #T_01e52_row4_col1 {
#   background-color: #a10e15;
# }
# #T_01e52_row0_col2, #T_01e52_row1_col2, #T_01e52_row4_col2 {
#   background-color: #980c13;
# }
# #T_01e52_row0_col3, #T_01e52_row0_col4, #T_01e52_row1_col0, #T_01e52_row1_col1, #T_01e52_row4_col3, #T_01e52_row4_col4, #T_01e52_row8_col0, #T_01e52_row8_col1 {
#   background-color: #800610;
# }
# #T_01e52_row0_col5, #T_01e52_row4_col5 {
#   background-color: #8e0912;
# }
# #T_01e52_row0_col6, #T_01e52_row0_col7, #T_01e52_row0_col8, #T_01e52_row4_col6, #T_01e52_row4_col7, #T_01e52_row4_col8 {
#   background-color: #940b13;
# }
# #T_01e52_row1_col3, #T_01e52_row1_col4 {
#   background-color: #8a0812;
# }
# #T_01e52_row1_col5, #T_01e52_row1_col8, #T_01e52_row18_col0 {
#   background-color: #9d0d14;
# }
# #T_01e52_row1_col6, #T_01e52_row1_col7, #T_01e52_row7_col0, #T_01e52_row7_col1 {
#   background-color: #820711;
# }
# #T_01e52_row2_col0, #T_01e52_row2_col1, #T_01e52_row2_col2, #T_01e52_row2_col8, #T_01e52_row18_col7 {
#   background-color: #860811;
# }
# #T_01e52_row2_col3, #T_01e52_row2_col4, #T_01e52_row6_col2, #T_01e52_row10_col2, #T_01e52_row10_col8, #T_01e52_row16_col2, #T_01e52_row18_col4 {
#   background-color: #73030f;
# }
# #T_01e52_row2_col5, #T_01e52_row2_col6, #T_01e52_row2_col7, #T_01e52_row9_col0, #T_01e52_row9_col1, #T_01e52_row10_col0, #T_01e52_row10_col1 {
#   background-color: #7c0510;
# }
# #T_01e52_row3_col0, #T_01e52_row3_col1 {
#   background-color: #a91016;
# }
# #T_01e52_row3_col2 {
#   background-color: #ce1a1e;
# }
# #T_01e52_row3_col3, #T_01e52_row3_col4 {
#   background-color: #c1161b;
# }
# #T_01e52_row3_col5 {
#   background-color: #d42121;
# }
# #T_01e52_row3_col6, #T_01e52_row3_col7 {
#   background-color: #b21218;
# }
# #T_01e52_row3_col8 {
#   background-color: #d52221;
# }
# #T_01e52_row5_col0, #T_01e52_row5_col1, #T_01e52_row6_col0, #T_01e52_row6_col1, #T_01e52_row18_col3 {
#   background-color: #7e0610;
# }
# #T_01e52_row5_col2, #T_01e52_row5_col6, #T_01e52_row5_col7, #T_01e52_row6_col6, #T_01e52_row6_col7, #T_01e52_row6_col8 {
#   background-color: #77040f;
# }
# #T_01e52_row5_col3, #T_01e52_row5_col4, #T_01e52_row6_col3, #T_01e52_row6_col4, #T_01e52_row9_col3, #T_01e52_row9_col4, #T_01e52_row10_col3, #T_01e52_row10_col4, #T_01e52_row15_col0, #T_01e52_row15_col1, #T_01e52_row15_col2, #T_01e52_row16_col5, #T_01e52_row17_col0, #T_01e52_row17_col1, #T_01e52_row17_col2, #T_01e52_row17_col5, #T_01e52_row17_col6, #T_01e52_row17_col7, #T_01e52_row17_col8 {
#   background-color: #67000d;
# }
# #T_01e52_row5_col5, #T_01e52_row6_col5, #T_01e52_row15_col3, #T_01e52_row15_col4, #T_01e52_row15_col8 {
#   background-color: #6d010e;
# }
# #T_01e52_row5_col8, #T_01e52_row9_col6, #T_01e52_row9_col7, #T_01e52_row10_col6, #T_01e52_row10_col7, #T_01e52_row16_col6, #T_01e52_row16_col7 {
#   background-color: #75030f;
# }
# #T_01e52_row7_col2, #T_01e52_row7_col8, #T_01e52_row8_col6, #T_01e52_row8_col7, #T_01e52_row16_col0, #T_01e52_row16_col1 {
#   background-color: #79040f;
# }
# #T_01e52_row7_col3, #T_01e52_row7_col4, #T_01e52_row9_col5, #T_01e52_row10_col5, #T_01e52_row15_col6, #T_01e52_row15_col7, #T_01e52_row17_col3, #T_01e52_row17_col4 {
#   background-color: #69000d;
# }
# #T_01e52_row7_col5, #T_01e52_row15_col5, #T_01e52_row16_col3, #T_01e52_row16_col4, #T_01e52_row16_col8 {
#   background-color: #6f020e;
# }
# #T_01e52_row7_col6, #T_01e52_row7_col7, #T_01e52_row8_col2, #T_01e52_row8_col8 {
#   background-color: #7a0510;
# }
# #T_01e52_row8_col3, #T_01e52_row8_col4 {
#   background-color: #6b010e;
# }
# #T_01e52_row8_col5, #T_01e52_row9_col2, #T_01e52_row9_col8 {
#   background-color: #71020e;
# }
# #T_01e52_row11_col0, #T_01e52_row11_col1, #T_01e52_row11_col6, #T_01e52_row11_col7 {
#   background-color: #d01d1f;
# }
# #T_01e52_row11_col2 {
#   background-color: #f34935;
# }
# #T_01e52_row11_col3, #T_01e52_row11_col4 {
#   background-color: #e32f27;
# }
# #T_01e52_row11_col5 {
#   background-color: #f34c37;
# }
# #T_01e52_row11_col8 {
#   background-color: #f14331;
# }
# #T_01e52_row12_col0, #T_01e52_row12_col1, #T_01e52_row12_col2, #T_01e52_row12_col3, #T_01e52_row12_col4, #T_01e52_row12_col5, #T_01e52_row12_col6, #T_01e52_row12_col7, #T_01e52_row12_col8 {
#   background-color: #fb7c5c;
# }
# #T_01e52_row13_col0, #T_01e52_row13_col1, #T_01e52_row14_col0, #T_01e52_row14_col1, #T_01e52_row19_col0, #T_01e52_row19_col1 {
#   background-color: #cf1c1f;
# }
# #T_01e52_row13_col2, #T_01e52_row13_col8, #T_01e52_row14_col2, #T_01e52_row14_col8, #T_01e52_row19_col2, #T_01e52_row19_col8 {
#   background-color: #bf151b;
# }
# #T_01e52_row13_col3, #T_01e52_row13_col4, #T_01e52_row14_col3, #T_01e52_row14_col4, #T_01e52_row19_col3, #T_01e52_row19_col4 {
#   background-color: #b61319;
# }
# #T_01e52_row13_col5, #T_01e52_row13_col6, #T_01e52_row13_col7, #T_01e52_row14_col5, #T_01e52_row14_col6, #T_01e52_row14_col7, #T_01e52_row19_col5 {
#   background-color: #c4161c;
# }
# #T_01e52_row18_col1 {
#   background-color: #900a12;
# }
# #T_01e52_row18_col2, #T_01e52_row18_col8 {
#   background-color: #920a13;
# }
# #T_01e52_row18_col5 {
#   background-color: #840711;
# }
# #T_01e52_row18_col6 {
#   background-color: #960b13;
# }
# #T_01e52_row19_col6, #T_01e52_row19_col7 {
#   background-color: #c5171c;
# }
# #T_01e52_row20_col0, #T_01e52_row20_col1, #T_01e52_row21_col0, #T_01e52_row21_col1 {
#   background-color: #cc191e;
# }
# #T_01e52_row20_col2, #T_01e52_row21_col2 {
#   background-color: #be151a;
# }
# #T_01e52_row20_col3, #T_01e52_row20_col4, #T_01e52_row21_col3, #T_01e52_row21_col4 {
#   background-color: #b31218;
# }
# #T_01e52_row20_col5 {
#   background-color: #c2161b;
# }
# #T_01e52_row20_col6, #T_01e52_row20_col7, #T_01e52_row21_col5, #T_01e52_row21_col6, #T_01e52_row21_col7 {
#   background-color: #c3161b;
# }
# #T_01e52_row20_col8, #T_01e52_row21_col8 {
#   background-color: #bd151a;
# }
# </style>
# <table id="T_01e52_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="9">XSUM, bloomz3b</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" colspan="3">Rouge_rouge1</th>
#       <th class="col_heading level1 col3" colspan="3">Rouge_rouge2</th>
#       <th class="col_heading level1 col6" colspan="3">Rouge_rougeL</th>
#     </tr>
#     <tr>
#       <th class="blank level2" >&nbsp;</th>
#       <th class="col_heading level2 col0" >prr</th>
#       <th class="col_heading level2 col1" >rcc-auc</th>
#       <th class="col_heading level2 col2" >rpp</th>
#       <th class="col_heading level2 col3" >prr</th>
#       <th class="col_heading level2 col4" >rcc-auc</th>
#       <th class="col_heading level2 col5" >rpp</th>
#       <th class="col_heading level2 col6" >prr</th>
#       <th class="col_heading level2 col7" >rcc-auc</th>
#       <th class="col_heading level2 col8" >rpp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_01e52_level0_row0" class="row_heading level0 row0" >MaxProbabilitySeq</th>
#       <td id="T_01e52_row0_col0" class="data row0 col0" >33.34 ± 0.00</td>
#       <td id="T_01e52_row0_col1" class="data row0 col1" >66.66 ± 0.00</td>
#       <td id="T_01e52_row0_col2" class="data row0 col2" >16.50 ± 0.00</td>
#       <td id="T_01e52_row0_col3" class="data row0 col3" >11.88 ± 0.00</td>
#       <td id="T_01e52_row0_col4" class="data row0 col4" >88.12 ± 0.00</td>
#       <td id="T_01e52_row0_col5" class="data row0 col5" >16.59 ± 0.00</td>
#       <td id="T_01e52_row0_col6" class="data row0 col6" >27.38 ± 0.00</td>
#       <td id="T_01e52_row0_col7" class="data row0 col7" >72.62 ± 0.00</td>
#       <td id="T_01e52_row0_col8" class="data row0 col8" >16.20 ± 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_01e52_level0_row1" class="row_heading level0 row1" >MaxProbabilityNormalizedSeq</th>
#       <td id="T_01e52_row1_col0" class="data row1 col0" >31.73 ± 0

# %%
pretty_plot(
    'MT, Dolly3b',
    ['/Users/ekaterinafadeeva/work/data/uncertainty_mans/ue_mans/wmt_dolly3b_seed' + str(x)
     for x in range(1, 10)])
# Out:
# Will measure variance using 9 seeds
# <style type="text/css">
# #T_a1bce_ td:hover {
#   background-color: #ffffb3;
# }
# #T_a1bce_ .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_a1bce_ th.col3 {
#   border-left: 1px solid black;
# }
# #T_a1bce_ td.col3 {
#   border-left: 1px solid black;
# }
# #T_a1bce_ th.col6 {
#   border-left: 1px solid black;
# }
# #T_a1bce_ td.col6 {
#   border-left: 1px solid black;
# }
# #T_a1bce_row0_col0, #T_a1bce_row4_col0, #T_a1bce_row21_col6 {
#   background-color: #c2161b;
# }
# #T_a1bce_row0_col1, #T_a1bce_row4_col1, #T_a1bce_row21_col7 {
#   background-color: #c3161b;
# }
# #T_a1bce_row0_col2, #T_a1bce_row4_col2, #T_a1bce_row7_col1, #T_a1bce_row8_col1, #T_a1bce_row21_col2 {
#   background-color: #d92523;
# }
# #T_a1bce_row0_col3, #T_a1bce_row4_col3, #T_a1bce_row19_col6, #T_a1bce_row20_col3 {
#   background-color: #bf151b;
# }
# #T_a1bce_row0_col4, #T_a1bce_row4_col4, #T_a1bce_row19_col1, #T_a1bce_row20_col4, #T_a1bce_row21_col0 {
#   background-color: #bc141a;
# }
# #T_a1bce_row0_col5, #T_a1bce_row4_col5, #T_a1bce_row6_col2 {
#   background-color: #e63328;
# }
# #T_a1bce_row0_col6, #T_a1bce_row4_col6, #T_a1bce_row20_col7 {
#   background-color: #b81419;
# }
# #T_a1bce_row0_col7, #T_a1bce_row4_col7 {
#   background-color: #b91419;
# }
# #T_a1bce_row0_col8, #T_a1bce_row4_col8, #T_a1bce_row9_col4 {
#   background-color: #d32020;
# }
# #T_a1bce_row1_col0, #T_a1bce_row1_col1 {
#   background-color: #f34a36;
# }
# #T_a1bce_row1_col2 {
#   background-color: #ed392b;
# }
# #T_a1bce_row1_col3, #T_a1bce_row1_col5, #T_a1bce_row9_col5 {
#   background-color: #f24633;
# }
# #T_a1bce_row1_col4, #T_a1bce_row10_col5, #T_a1bce_row12_col8 {
#   background-color: #f14432;
# }
# #T_a1bce_row1_col6, #T_a1bce_row1_col7, #T_a1bce_row12_col5 {
#   background-color: #f14130;
# }
# #T_a1bce_row1_col8, #T_a1bce_row11_col3 {
#   background-color: #ea362a;
# }
# #T_a1bce_row2_col0, #T_a1bce_row2_col1 {
#   background-color: #d52221;
# }
# #T_a1bce_row2_col2, #T_a1bce_row9_col8, #T_a1bce_row11_col1 {
#   background-color: #e43027;
# }
# #T_a1bce_row2_col3, #T_a1bce_row6_col1, #T_a1bce_row7_col4, #T_a1bce_row8_col4, #T_a1bce_row10_col4, #T_a1bce_row18_col5 {
#   background-color: #d21f20;
# }
# #T_a1bce_row2_col4, #T_a1bce_row6_col0, #T_a1bce_row20_col8 {
#   background-color: #d11e1f;
# }
# #T_a1bce_row2_col5, #T_a1bce_row6_col5, #T_a1bce_row12_col2 {
#   background-color: #f0402f;
# }
# #T_a1bce_row2_col6, #T_a1bce_row2_col7, #T_a1bce_row6_col4, #T_a1bce_row12_col0, #T_a1bce_row20_col2 {
#   background-color: #cc191e;
# }
# #T_a1bce_row2_col8 {
#   background-color: #e02c26;
# }
# #T_a1bce_row3_col0, #T_a1bce_row3_col1, #T_a1bce_row3_col2, #T_a1bce_row3_col3, #T_a1bce_row3_col4, #T_a1bce_row3_col5, #T_a1bce_row3_col6, #T_a1bce_row3_col7, #T_a1bce_row3_col8 {
#   background-color: #fb7c5c;
# }
# #T_a1bce_row5_col0, #T_a1bce_row5_col1, #T_a1bce_row12_col1, #T_a1bce_row12_col3 {
#   background-color: #ce1a1e;
# }
# #T_a1bce_row5_col2, #T_a1bce_row6_col8, #T_a1bce_row8_col8, #T_a1bce_row20_col5 {
#   background-color: #e22e27;
# }
# #T_a1bce_row5_col3 {
#   background-color: #c8171c;
# }
# #T_a1bce_row5_col4, #T_a1bce_row5_col6 {
#   background-color: #c5171c;
# }
# #T_a1bce_row5_col5, #T_a1bce_row21_col5 {
#   background-color: #ec382b;
# }
# #T_a1bce_row5_col7, #T_a1bce_row19_col3, #T_a1bce_row21_col4 {
#   background-color: #c7171c;
# }
# #T_a1bce_row5_col8, #T_a1bce_row18_col8 {
#   background-color: #dd2a25;
# }
# #T_a1bce_row6_col3, #T_a1bce_row7_col6, #T_a1bce_row8_col6, #T_a1bce_row9_col6, #T_a1bce_row10_col6, #T_a1bce_row10_col7, #T_a1bce_row12_col6 {
#   background-color: #cf1c1f;
# }
# #T_a1bce_row6_col6, #T_a1bce_row21_col3 {
#   background-color: #c9181d;
# }
# #T_a1bce_row6_col7 {
#   background-color: #ca181d;
# }
# #T_a1bce_row7_col0, #T_a1bce_row8_col0, #T_a1bce_row9_col0, #T_a1bce_row9_col1, #T_a1bce_row10_col1, #T_a1bce_row18_col2, #T_a1bce_row19_col2 {
#   background-color: #d82422;
# }
# #T_a1bce_row7_col2, #T_a1bce_row8_col2, #T_a1bce_row10_col2, #T_a1bce_row11_col6, #T_a1bce_row11_col7 {
#   background-color: #e83429;
# }
# #T_a1bce_row7_col3, #T_a1bce_row8_col3, #T_a1bce_row9_col3, #T_a1bce_row10_col3 {
#   background-color: #d42121;
# }
# #T_a1bce_row7_col5, #T_a1bce_row8_col5 {
#   background-color: #f14331;
# }
# #T_a1bce_row7_col7, #T_a1bce_row8_col7, #T_a1bce_row9_col7, #T_a1bce_row12_col7, #T_a1bce_row13_col8, #T_a1bce_row14_col8 {
#   background-color: #d01d1f;
# }
# #T_a1bce_row7_col8, #T_a1bce_row10_col8, #T_a1bce_row11_col0 {
#   background-color: #e32f27;
# }
# #T_a1bce_row9_col2, #T_a1bce_row11_col4 {
#   background-color: #e93529;
# }
# #T_a1bce_row10_col0 {
#   background-color: #d72322;
# }
# #T_a1bce_row11_col2 {
#   background-color: #f44f39;
# }
# #T_a1bce_row11_col5 {
#   background-color: #f75c41;
# }
# #T_a1bce_row11_col8 {
#   background-color: #f6553c;
# }
# #T_a1bce_row12_col4, #T_a1bce_row13_col2, #T_a1bce_row14_col2 {
#   background-color: #cb181d;
# }
# #T_a1bce_row13_col0, #T_a1bce_row14_col0 {
#   background-color: #b01217;
# }
# #T_a1bce_row13_col1, #T_a1bce_row14_col1 {
#   background-color: #b11218;
# }
# #T_a1bce_row13_col3, #T_a1bce_row14_col3, #T_a1bce_row21_col1 {
#   background-color: #bd151a;
# }
# #T_a1bce_row13_col4, #T_a1bce_row14_col4, #T_a1bce_row19_col0 {
#   background-color: #bb141a;
# }
# #T_a1bce_row13_col5, #T_a1bce_row14_col5 {
#   background-color: #e12d26;
# }
# #T_a1bce_row13_col6, #T_a1bce_row14_col6 {
#   background-color: #b51318;
# }
# #T_a1bce_row13_col7, #T_a1bce_row14_col7 {
#   background-color: #b61319;
# }
# #T_a1bce_row15_col0, #T_a1bce_row15_col2, #T_a1bce_row15_col8, #T_a1bce_row16_col0, #T_a1bce_row16_col1, #T_a1bce_row16_col3, #T_a1bce_row16_col4, #T_a1bce_row16_col5, #T_a1bce_row16_col6, #T_a1bce_row16_col7, #T_a1bce_row17_col0, #T_a1bce_row17_col2, #T_a1bce_row17_col6, #T_a1bce_row17_col8 {
#   background-color: #67000d;
# }
# #T_a1bce_row15_col1, #T_a1bce_row17_col1 {
#   background-color: #6f020e;
# }
# #T_a1bce_row15_col3 {
#   background-color: #840711;
# }
# #T_a1bce_row15_col4, #T_a1bce_row15_col5, #T_a1bce_row17_col3 {
#   background-color: #860811;
# }
# #T_a1bce_row15_col6 {
#   background-color: #69000d;
# }
# #T_a1bce_row15_col7, #T_a1bce_row16_col2, #T_a1bce_row16_col8, #T_a1bce_row17_col7 {
#   background-color: #71020e;
# }
# #T_a1bce_row17_col4 {
#   background-color: #880811;
# }
# #T_a1bce_row17_col5 {
#   background-color: #8c0912;
# }
# #T_a1bce_row18_col0 {
#   background-color: #9c0d14;
# }
# #T_a1bce_row18_col1 {
#   background-color: #aa1016;
# }
# #T_a1bce_row18_col3 {
#   background-color: #9a0c14;
# }
# #T_a1bce_row18_col4 {
#   background-color: #af1117;
# }
# #T_a1bce_row18_col6 {
#   background-color: #a10e15;
# }
# #T_a1bce_row18_col7 {
#   background-color: #ac1117;
# }
# #T_a1bce_row19_col4 {
#   background-color: #c4161c;
# }
# #T_a1bce_row19_col5 {
#   background-color: #eb372a;
# }
# #T_a1bce_row19_col7 {
#   background-color: #c1161b;
# }
# #T_a1bce_row19_col8 {
#   background-color: #db2824;
# }
# #T_a1bce_row20_col0 {
#   background-color: #b21218;
# }
# #T_a1bce_row20_col1 {
#   background-color: #b31218;
# }
# #T_a1bce_row20_col6 {
#   background-color: #b71319;
# }
# #T_a1bce_row21_col8 {
#   background-color: #dc2924;
# }
# </style>
# <table id="T_a1bce_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="9">MT, Dolly3b</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" colspan="3">Rouge_rouge1</th>
#       <th class="col_heading level1 col3" colspan="3">Rouge_rouge2</th>
#       <th class="col_heading level1 col6" colspan="3">Rouge_rougeL</th>
#     </tr>
#     <tr>
#       <th class="blank level2" >&nbsp;</th>
#       <th class="col_heading level2 col0" >prr</th>
#       <th class="col_heading level2 col1" >rcc-auc</th>
#       <th class="col_heading level2 col2" >rpp</th>
#       <th class="col_heading level2 col3" >prr</th>
#       <th class="col_heading level2 col4" >rcc-auc</th>
#       <th class="col_heading level2 col5" >rpp</th>
#       <th class="col_heading level2 col6" >prr</th>
#       <th class="col_heading level2 col7" >rcc-auc</th>
#       <th class="col_heading level2 col8" >rpp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1bce_level0_row0" class="row_heading level0 row0" >MaxProbabilitySeq</th>
#       <td id="T_a1bce_row0_col0" class="data row0 col0" >17.68 ±

# %%
pretty_plot(
    'MT, Bloomz3b',
    ['/Users/ekaterinafadeeva/work/data/uncertainty_mans/ue_mans/wmt_bloomz3b_seed' + str(x)
     for x in range(1, 10)])
# Out:
# Will measure variance using 9 seeds
# <style type="text/css">
# #T_e61bd_ td:hover {
#   background-color: #ffffb3;
# }
# #T_e61bd_ .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_e61bd_ th.col3 {
#   border-left: 1px solid black;
# }
# #T_e61bd_ td.col3 {
#   border-left: 1px solid black;
# }
# #T_e61bd_ th.col6 {
#   border-left: 1px solid black;
# }
# #T_e61bd_ td.col6 {
#   border-left: 1px solid black;
# }
# #T_e61bd_row0_col0, #T_e61bd_row0_col1, #T_e61bd_row0_col6, #T_e61bd_row0_col7, #T_e61bd_row4_col0, #T_e61bd_row4_col1, #T_e61bd_row4_col6, #T_e61bd_row4_col7 {
#   background-color: #b21218;
# }
# #T_e61bd_row0_col2, #T_e61bd_row0_col8, #T_e61bd_row4_col2, #T_e61bd_row4_col8 {
#   background-color: #c5171c;
# }
# #T_e61bd_row0_col3, #T_e61bd_row0_col4, #T_e61bd_row4_col3, #T_e61bd_row4_col4 {
#   background-color: #a50f15;
# }
# #T_e61bd_row0_col5, #T_e61bd_row4_col5 {
#   background-color: #bc141a;
# }
# #T_e61bd_row1_col0, #T_e61bd_row1_col1, #T_e61bd_row1_col2, #T_e61bd_row1_col6, #T_e61bd_row1_col7, #T_e61bd_row1_col8, #T_e61bd_row2_col3, #T_e61bd_row2_col4, #T_e61bd_row2_col5 {
#   background-color: #67000d;
# }
# #T_e61bd_row1_col3, #T_e61bd_row1_col4, #T_e61bd_row5_col3, #T_e61bd_row5_col4, #T_e61bd_row8_col5, #T_e61bd_row10_col5 {
#   background-color: #73030f;
# }
# #T_e61bd_row1_col5, #T_e61bd_row2_col8 {
#   background-color: #69000d;
# }
# #T_e61bd_row2_col0, #T_e61bd_row2_col1, #T_e61bd_row3_col6, #T_e61bd_row3_col7, #T_e61bd_row7_col3, #T_e61bd_row7_col4 {
#   background-color: #71020e;
# }
# #T_e61bd_row2_col2 {
#   background-color: #6b010e;
# }
# #T_e61bd_row2_col6, #T_e61bd_row2_col7, #T_e61bd_row3_col0, #T_e61bd_row3_col1, #T_e61bd_row8_col3, #T_e61bd_row8_col4, #T_e61bd_row9_col3, #T_e61bd_row9_col4 {
#   background-color: #6f020e;
# }
# #T_e61bd_row3_col2, #T_e61bd_row8_col6, #T_e61bd_row8_col7, #T_e61bd_row9_col2, #T_e61bd_row15_col2 {
#   background-color: #7a0510;
# }
# #T_e61bd_row3_col3, #T_e61bd_row3_col4, #T_e61bd_row16_col2 {
#   background-color: #900a12;
# }
# #T_e61bd_row3_col5, #T_e61bd_row6_col2 {
#   background-color: #860811;
# }
# #T_e61bd_row3_col8, #T_e61bd_row5_col6, #T_e61bd_row5_col7, #T_e61bd_row6_col5, #T_e61bd_row7_col6, #T_e61bd_row7_col7, #T_e61bd_row8_col0, #T_e61bd_row8_col1, #T_e61bd_row8_col2, #T_e61bd_row8_col8, #T_e61bd_row16_col5 {
#   background-color: #7c0510;
# }
# #T_e61bd_row5_col0, #T_e61bd_row5_col1, #T_e61bd_row5_col8, #T_e61bd_row7_col0, #T_e61bd_row7_col1, #T_e61bd_row7_col8 {
#   background-color: #7e0610;
# }
# #T_e61bd_row5_col2, #T_e61bd_row6_col6, #T_e61bd_row6_col7, #T_e61bd_row7_col2 {
#   background-color: #800610;
# }
# #T_e61bd_row5_col5, #T_e61bd_row9_col0, #T_e61bd_row9_col1, #T_e61bd_row9_col8, #T_e61bd_row10_col0, #T_e61bd_row10_col1, #T_e61bd_row10_col2, #T_e61bd_row15_col0, #T_e61bd_row15_col1, #T_e61bd_row15_col3, #T_e61bd_row15_col4, #T_e61bd_row15_col5, #T_e61bd_row15_col8, #T_e61bd_row17_col2, #T_e61bd_row17_col5 {
#   background-color: #79040f;
# }
# #T_e61bd_row6_col0, #T_e61bd_row6_col1 {
#   background-color: #820711;
# }
# #T_e61bd_row6_col3, #T_e61bd_row6_col4, #T_e61bd_row9_col6, #T_e61bd_row9_col7, #T_e61bd_row10_col6, #T_e61bd_row10_col7, #T_e61bd_row10_col8, #T_e61bd_row15_col6, #T_e61bd_row15_col7, #T_e61bd_row16_col3, #T_e61bd_row16_col4, #T_e61bd_row17_col0, #T_e61bd_row17_col1, #T_e61bd_row17_col3, #T_e61bd_row17_col4 {
#   background-color: #77040f;
# }
# #T_e61bd_row6_col8 {
#   background-color: #840711;
# }
# #T_e61bd_row7_col5, #T_e61bd_row9_col5, #T_e61bd_row17_col6, #T_e61bd_row17_col7, #T_e61bd_row17_col8 {
#   background-color: #75030f;
# }
# #T_e61bd_row10_col3, #T_e61bd_row10_col4 {
#   background-color: #6d010e;
# }
# #T_e61bd_row11_col0, #T_e61bd_row11_col1 {
#   background-color: #9d0d14;
# }
# #T_e61bd_row11_col2 {
#   background-color: #bb141a;
# }
# #T_e61bd_row11_col3, #T_e61bd_row11_col4 {
#   background-color: #c1161b;
# }
# #T_e61bd_row11_col5 {
#   background-color: #c2161b;
# }
# #T_e61bd_row11_col6, #T_e61bd_row11_col7 {
#   background-color: #a10e15;
# }
# #T_e61bd_row11_col8 {
#   background-color: #b91419;
# }
# #T_e61bd_row12_col0, #T_e61bd_row12_col1 {
#   background-color: #fa6648;
# }
# #T_e61bd_row12_col2, #T_e61bd_row21_col3, #T_e61bd_row21_col4 {
#   background-color: #fb7050;
# }
# #T_e61bd_row12_col3, #T_e61bd_row12_col4 {
#   background-color: #f96346;
# }
# #T_e61bd_row12_col5, #T_e61bd_row12_col6, #T_e61bd_row12_col7 {
#   background-color: #fb694a;
# }
# #T_e61bd_row12_col8 {
#   background-color: #fb7252;
# }
# #T_e61bd_row13_col0, #T_e61bd_row13_col1, #T_e61bd_row13_col2, #T_e61bd_row13_col3, #T_e61bd_row13_col4, #T_e61bd_row13_col5, #T_e61bd_row13_col6, #T_e61bd_row13_col7, #T_e61bd_row13_col8, #T_e61bd_row14_col0, #T_e61bd_row14_col1, #T_e61bd_row14_col2, #T_e61bd_row14_col3, #T_e61bd_row14_col4, #T_e61bd_row14_col5, #T_e61bd_row14_col6, #T_e61bd_row14_col7, #T_e61bd_row14_col8 {
#   background-color: #fb7c5c;
# }
# #T_e61bd_row16_col0, #T_e61bd_row16_col6, #T_e61bd_row16_col7 {
#   background-color: #880811;
# }
# #T_e61bd_row16_col1 {
#   background-color: #8a0812;
# }
# #T_e61bd_row16_col8 {
#   background-color: #8c0912;
# }
# #T_e61bd_row18_col0, #T_e61bd_row18_col1, #T_e61bd_row18_col7 {
#   background-color: #cc191e;
# }
# #T_e61bd_row18_col2 {
#   background-color: #e43027;
# }
# #T_e61bd_row18_col3 {
#   background-color: #be151a;
# }
# #T_e61bd_row18_col4 {
#   background-color: #b81419;
# }
# #T_e61bd_row18_col5, #T_e61bd_row18_col6 {
#   background-color: #cf1c1f;
# }
# #T_e61bd_row18_col8 {
#   background-color: #e53228;
# }
# #T_e61bd_row19_col0, #T_e61bd_row19_col1, #T_e61bd_row19_col6, #T_e61bd_row19_col7 {
#   background-color: #fb7757;
# }
# #T_e61bd_row19_col2, #T_e61bd_row19_col5, #T_e61bd_row19_col8, #T_e61bd_row20_col3, #T_e61bd_row20_col4 {
#   background-color: #fb7656;
# }
# #T_e61bd_row19_col3, #T_e61bd_row19_col4, #T_e61bd_row21_col0, #T_e61bd_row21_col1 {
#   background-color: #fb7555;
# }
# #T_e61bd_row20_col0, #T_e61bd_row20_col1, #T_e61bd_row20_col6, #T_e61bd_row20_col7 {
#   background-color: #fb7858;
# }
# #T_e61bd_row20_col2, #T_e61bd_row20_col5, #T_e61bd_row20_col8 {
#   background-color: #fb7a5a;
# }
# #T_e61bd_row21_col2, #T_e61bd_row21_col5, #T_e61bd_row21_col6, #T_e61bd_row21_col7, #T_e61bd_row21_col8 {
#   background-color: #fb7353;
# }
# </style>
# <table id="T_e61bd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="9">MT, Bloomz3b</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" colspan="3">Rouge_rouge1</th>
#       <th class="col_heading level1 col3" colspan="3">Rouge_rouge2</th>
#       <th class="col_heading level1 col6" colspan="3">Rouge_rougeL</th>
#     </tr>
#     <tr>
#       <th class="blank level2" >&nbsp;</th>
#       <th class="col_heading level2 col0" >prr</th>
#       <th class="col_heading level2 col1" >rcc-auc</th>
#       <th class="col_heading level2 col2" >rpp</th>
#       <th class="col_heading level2 col3" >prr</th>
#       <th class="col_heading level2 col4" >rcc-auc</th>
#       <th class="col_heading level2 col5" >rpp</th>
#       <th class="col_heading level2 col6" >prr</th>
#       <th class="col_heading level2 col7" >rcc-auc</th>
#       <th class="col_heading level2 col8" >rpp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e61bd_level0_row0" class="row_heading level0 row0" >MaxProbabilitySeq</th>
#       <td id="T_e61bd_row0_col0" class="data row0 col0" >13.43 ± 0.20</td>
#       <td id="T_e61bd_row0_col1" class="data row0 col1" >86.57 ± 0.20</td>
#       <td id="T_e61bd_row0_col2" class="data row0 col2" >11.53 ± 0.10</td>
#       <td id="T_e61bd_row0_col3" class="data row0 col3" >4.53 ± 0.08</td>
#       <td id="T_e61bd_row0_col4" class="data row0 col4" >95.47 ± 0.08</td>
#       <td id="T_e61bd_row0_col5" class="data row0 col5" >9.66 ± 0.06</td>
#       <td id="T_e61bd_row0_col6" class="data row0 col6" >11.98 ± 0.17</td>
#       <td id="T_e61bd_row0_col7" class="data row0 col7" >88.02 ± 0.17</td>
#       <td id="T_e61bd_row0_col8" class="data row0 col8" >11.67 ± 0.11</td>
#     </tr>
#     <tr>
#       <th id="T_e61bd_level0_row1" class="row_heading level0 row1" >MaxProbabilityNormalizedSeq</th>
#       <td id="T_e61bd_row1_col0" class="data row1 col0" >8.09 ± 0.14</

# %%
pretty_plot(
    ['TriviaQA, Dolly3b', 'XSUM, Dolly3b', 'MT, Dolly3b'],
    [
        ['/Users/ekaterinafadeeva/work/data/uncertainty_mans/ue_mans/qa_dolly3b_seed' + str(x) for x in range(2, 9)],
        ['/Users/ekaterinafadeeva/work/data/uncertainty_mans/ue_mans/xsum_dolly3b_seed' + str(x) for x in range(2, 10)],
        ['/Users/ekaterinafadeeva/work/data/uncertainty_mans/ue_mans/wmt_dolly3b_seed' + str(x) for x in range(2, 10)],
    ], level='token')
# Out:
# Will measure variance using 7 seeds
# Will measure variance using 8 seeds
# Will measure variance using 8 seeds
# <style type="text/css">
# #T_680b7_ td:hover {
#   background-color: #ffffb3;
# }
# #T_680b7_ .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_680b7_ th.col3 {
#   border-left: 1px solid black;
# }
# #T_680b7_ td.col3 {
#   border-left: 1px solid black;
# }
# #T_680b7_ th.col6 {
#   border-left: 2px solid black;
# }
# #T_680b7_ td.col6 {
#   border-left: 2px solid black;
# }
# #T_680b7_ th.col9 {
#   border-left: 1px solid black;
# }
# #T_680b7_ td.col9 {
#   border-left: 1px solid black;
# }
# #T_680b7_ th.col12 {
#   border-left: 2px solid black;
# }
# #T_680b7_ td.col12 {
#   border-left: 2px solid black;
# }
# #T_680b7_ th.col15 {
#   border-left: 1px solid black;
# }
# #T_680b7_ td.col15 {
#   border-left: 1px solid black;
# }
# #T_680b7_row0_col0, #T_680b7_row0_col1, #T_680b7_row0_col5, #T_680b7_row2_col0, #T_680b7_row2_col1, #T_680b7_row4_col0, #T_680b7_row4_col1, #T_680b7_row4_col5 {
#   background-color: #980c13;
# }
# #T_680b7_row0_col2, #T_680b7_row4_col2 {
#   background-color: #b61319;
# }
# #T_680b7_row0_col3, #T_680b7_row0_col4, #T_680b7_row3_col5, #T_680b7_row4_col3, #T_680b7_row4_col4, #T_680b7_row6_col14, #T_680b7_row11_col0, #T_680b7_row11_col1, #T_680b7_row11_col2, #T_680b7_row11_col6, #T_680b7_row11_col7, #T_680b7_row11_col8, #T_680b7_row11_col9, #T_680b7_row11_col10, #T_680b7_row11_col11, #T_680b7_row11_col12, #T_680b7_row11_col13, #T_680b7_row11_col15, #T_680b7_row11_col16, #T_680b7_row11_col17 {
#   background-color: #67000d;
# }
# #T_680b7_row0_col6, #T_680b7_row0_col7, #T_680b7_row4_col6, #T_680b7_row4_col7 {
#   background-color: #e93529;
# }
# #T_680b7_row0_col8, #T_680b7_row2_col8, #T_680b7_row4_col8 {
#   background-color: #f96346;
# }
# #T_680b7_row0_col9, #T_680b7_row0_col10, #T_680b7_row1_col14, #T_680b7_row4_col9, #T_680b7_row4_col10, #T_680b7_row7_col0, #T_680b7_row7_col1 {
#   background-color: #a91016;
# }
# #T_680b7_row0_col11, #T_680b7_row2_col17, #T_680b7_row4_col11 {
#   background-color: #cc191e;
# }
# #T_680b7_row0_col12, #T_680b7_row0_col13, #T_680b7_row4_col12, #T_680b7_row4_col13, #T_680b7_row8_col12, #T_680b7_row8_col13 {
#   background-color: #e02c26;
# }
# #T_680b7_row0_col14, #T_680b7_row4_col14, #T_680b7_row5_col3, #T_680b7_row5_col4 {
#   background-color: #840711;
# }
# #T_680b7_row0_col15, #T_680b7_row0_col16, #T_680b7_row2_col12, #T_680b7_row2_col13, #T_680b7_row4_col15, #T_680b7_row4_col16, #T_680b7_row5_col5, #T_680b7_row10_col12, #T_680b7_row10_col13 {
#   background-color: #aa1016;
# }
# #T_680b7_row0_col17, #T_680b7_row4_col17 {
#   background-color: #d72322;
# }
# #T_680b7_row1_col0, #T_680b7_row1_col1, #T_680b7_row6_col5, #T_680b7_row10_col15, #T_680b7_row10_col16 {
#   background-color: #c1161b;
# }
# #T_680b7_row1_col2, #T_680b7_row6_col8 {
#   background-color: #bf151b;
# }
# #T_680b7_row1_col3, #T_680b7_row1_col4, #T_680b7_row1_col5, #T_680b7_row1_col6, #T_680b7_row1_col7, #T_680b7_row1_col8, #T_680b7_row1_col9, #T_680b7_row1_col10, #T_680b7_row1_col15, #T_680b7_row1_col16, #T_680b7_row3_col0, #T_680b7_row3_col1, #T_680b7_row3_col2, #T_680b7_row3_col11, #T_680b7_row3_col12, #T_680b7_row3_col13, #T_680b7_row3_col14, #T_680b7_row3_col17, #T_680b7_row9_col11 {
#   background-color: #fb7c5c;
# }
# #T_680b7_row1_col11 {
#   background-color: #f5533b;
# }
# #T_680b7_row1_col12, #T_680b7_row1_col13, #T_680b7_row5_col11, #T_680b7_row9_col15, #T_680b7_row9_col16 {
#   background-color: #ca181d;
# }
# #T_680b7_row1_col17, #T_680b7_row5_col8 {
#   background-color: #fb7a5a;
# }
# #T_680b7_row2_col2, #T_680b7_row9_col3, #T_680b7_row9_col4, #T_680b7_row10_col3, #T_680b7_row10_col4 {
#   background-color: #b31218;
# }
# #T_680b7_row2_col3, #T_680b7_row2_col4, #T_680b7_row3_col3, #T_680b7_row3_col4 {
#   background-color: #6d010e;
# }
# #T_680b7_row2_col5, #T_680b7_row2_col14, #T_680b7_row6_col3, #T_680b7_row6_col4, #T_680b7_row9_col14 {
#   background-color: #960b13;
# }
# #T_680b7_row2_col6, #T_680b7_row2_col7 {
#   background-color: #e63328;
# }
# #T_680b7_row2_col9, #T_680b7_row2_col10 {
#   background-color: #9f0e14;
# }
# #T_680b7_row2_col11, #T_680b7_row8_col11 {
#   background-color: #be151a;
# }
# #T_680b7_row2_col15, #T_680b7_row2_col16, #T_680b7_row6_col17, #T_680b7_row11_col5 {
#   background-color: #b11218;
# }
# #T_680b7_row3_col6, #T_680b7_row3_col7 {
#   background-color: #fb7353;
# }
# #T_680b7_row3_col8 {
#   background-color: #f4503a;
# }
# #T_680b7_row3_col9, #T_680b7_row3_col10 {
#   background-color: #f96245;
# }
# #T_680b7_row3_col15, #T_680b7_row3_col16, #T_680b7_row5_col6, #T_680b7_row5_col7 {
#   background-color: #f7593f;
# }
# #T_680b7_row5_col0, #T_680b7_row5_col1, #T_680b7_row5_col14 {
#   background-color: #b91419;
# }
# #T_680b7_row5_col2 {
#   background-color: #bd151a;
# }
# #T_680b7_row5_col9, #T_680b7_row5_col10 {
#   background-color: #c3161b;
# }
# #T_680b7_row5_col12, #T_680b7_row5_col13 {
#   background-color: #f34c37;
# }
# #T_680b7_row5_col15, #T_680b7_row5_col16 {
#   background-color: #c9181d;
# }
# #T_680b7_row5_col17, #T_680b7_row9_col17 {
#   background-color: #e32f27;
# }
# #T_680b7_row6_col0, #T_680b7_row6_col1 {
#   background-color: #73030f;
# }
# #T_680b7_row6_col2 {
#   background-color: #69000d;
# }
# #T_680b7_row6_col6, #T_680b7_row6_col7, #T_680b7_row8_col17 {
#   background-color: #ce1a1e;
# }
# #T_680b7_row6_col9, #T_680b7_row6_col10 {
#   background-color: #dd2a25;
# }
# #T_680b7_row6_col11 {
#   background-color: #f6563d;
# }
# #T_680b7_row6_col12, #T_680b7_row6_col13 {
#   background-color: #920a13;
# }
# #T_680b7_row6_col15, #T_680b7_row6_col16 {
#   background-color: #900a12;
# }
# #T_680b7_row7_col2 {
#   background-color: #b81419;
# }
# #T_680b7_row7_col3, #T_680b7_row7_col4 {
#   background-color: #a30f15;
# }
# #T_680b7_row7_col5 {
#   background-color: #ab1016;
# }
# #T_680b7_row7_col6, #T_680b7_row7_col7 {
#   background-color: #f14130;
# }
# #T_680b7_row7_col8 {
#   background-color: #fb7151;
# }
# #T_680b7_row7_col9, #T_680b7_row7_col10, #T_680b7_row7_col14 {
#   background-color: #bb141a;
# }
# #T_680b7_row7_col11, #T_680b7_row10_col8 {
#   background-color: #c2161b;
# }
# #T_680b7_row7_col12, #T_680b7_row7_col13 {
#   background-color: #e43027;
# }
# #T_680b7_row7_col15, #T_680b7_row7_col16, #T_680b7_row8_col2 {
#   background-color: #b71319;
# }
# #T_680b7_row7_col17 {
#   background-color: #d21f20;
# }
# #T_680b7_row8_col0, #T_680b7_row8_col1 {
#   background-color: #a50f15;
# }
# #T_680b7_row8_col3, #T_680b7_row8_col4 {
#   background-color: #860811;
# }
# #T_680b7_row8_col5 {
#   background-color: #a10e15;
# }
# #T_680b7_row8_col6, #T_680b7_row8_col7 {
#   background-color: #ef3c2c;
# }
# #T_680b7_row8_col8 {
#   background-color: #fb6d4d;
# }
# #T_680b7_row8_col9, #T_680b7_row8_col10 {
#   background-color: #ac1117;
# }
# #T_680b7_row8_col14 {
#   background-color: #b21218;
# }
# #T_680b7_row8_col15, #T_680b7_row8_col16, #T_680b7_row9_col12, #T_680b7_row9_col13 {
#   background-color: #af1117;
# }
# #T_680b7_row9_col0, #T_680b7_row9_col1, #T_680b7_row10_col0, #T_680b7_row10_col1 {
#   background-color: #7a0510;
# }
# #T_680b7_row9_col2, #T_680b7_row10_col2 {
#   background-color: #75030f;
# }
# #T_680b7_row9_col5 {
#   background-color: #f0402f;
# }
# #T_680b7_row9_col6, #T_680b7_row9_col7 {
#   background-color: #d92523;
# }
# #T_680b7_row9_col8 {
#   background-color: #c8171c;
# }
# #T_680b7_row9_col9, #T_680b7_row9_col10, #T_680b7_row10_col9, #T_680b7_row10_col10 {
#   background-color: #eb372a;
# }
# #T_680b7_row10_col5 {
#   background-color: #f14331;
# }
# #T_680b7_row10_col6, #T_680b7_row10_col7 {
#   background-color: #d82422;
# }
# #T_680b7_row10_col11 {
#   background-color: #fb7858;
# }
# #T_680b7_row10_col14 {
#   background-color: #820711;
# }
# #T_680b7_row10_col17 {
#   background-color: #d52221;
# }
# #T_680b7_row11_col3, #T_680b7_row11_col4 {
#   background-color: #6f020e;
# }
# #T_680b7_row11_col14 {
#   background-color: #77040f;
# }
# </style>
# <table id="T_680b7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="6">TriviaQA, Dolly3b</th>
#       <th class="col_heading level0 col6" colspan="6">XSUM, Dolly3b</th>
#       <th class="col_heading level0 col12" colspan="6">MT, Dolly3b</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" colspan="3">BARTScoreToken-rh</th>
#       <th class="col_heading level1 col3" colspan="3">LCS</th>
#       <th class

# %%
pretty_plot(
    ['TriviaQA, Bloomz3b', 'XSUM, Bloomz3b', 'MT, Bloomz3b'],
    [
        ['/Users/ekaterinafadeeva/work/data/uncertainty_mans/ue_mans/qa_bloomz3b_seed' + str(x) for x in range(2, 10)],
        ['/Users/ekaterinafadeeva/work/data/uncertainty_mans/ue_mans/xsum_bloomz3b_seed' + str(x) for x in range(2, 10)],
        ['/Users/ekaterinafadeeva/work/data/uncertainty_mans/ue_mans/wmt_bloomz3b_seed' + str(x) for x in range(2, 10)],
    ], level='token')
# Out:
# Will measure variance using 8 seeds
# Will measure variance using 8 seeds
# Will measure variance using 8 seeds
# <style type="text/css">
# #T_51c6a_ td:hover {
#   background-color: #ffffb3;
# }
# #T_51c6a_ .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_51c6a_ th.col3 {
#   border-left: 1px solid black;
# }
# #T_51c6a_ td.col3 {
#   border-left: 1px solid black;
# }
# #T_51c6a_ th.col6 {
#   border-left: 2px solid black;
# }
# #T_51c6a_ td.col6 {
#   border-left: 2px solid black;
# }
# #T_51c6a_ th.col9 {
#   border-left: 1px solid black;
# }
# #T_51c6a_ td.col9 {
#   border-left: 1px solid black;
# }
# #T_51c6a_ th.col12 {
#   border-left: 2px solid black;
# }
# #T_51c6a_ td.col12 {
#   border-left: 2px solid black;
# }
# #T_51c6a_ th.col15 {
#   border-left: 1px solid black;
# }
# #T_51c6a_ td.col15 {
#   border-left: 1px solid black;
# }
# #T_51c6a_row0_col0, #T_51c6a_row0_col1, #T_51c6a_row4_col0, #T_51c6a_row4_col1 {
#   background-color: #9a0c14;
# }
# #T_51c6a_row0_col2, #T_51c6a_row0_col3, #T_51c6a_row0_col4, #T_51c6a_row4_col2, #T_51c6a_row4_col3, #T_51c6a_row4_col4 {
#   background-color: #f6563d;
# }
# #T_51c6a_row0_col5, #T_51c6a_row4_col5 {
#   background-color: #bf151b;
# }
# #T_51c6a_row0_col6, #T_51c6a_row0_col7, #T_51c6a_row4_col6, #T_51c6a_row4_col7 {
#   background-color: #b31218;
# }
# #T_51c6a_row0_col8, #T_51c6a_row4_col8 {
#   background-color: #f14432;
# }
# #T_51c6a_row0_col9, #T_51c6a_row0_col10, #T_51c6a_row4_col9, #T_51c6a_row4_col10, #T_51c6a_row6_col12, #T_51c6a_row6_col13 {
#   background-color: #a60f15;
# }
# #T_51c6a_row0_col11, #T_51c6a_row4_col11, #T_51c6a_row11_col3, #T_51c6a_row11_col4 {
#   background-color: #ad1117;
# }
# #T_51c6a_row0_col12, #T_51c6a_row0_col13, #T_51c6a_row4_col12, #T_51c6a_row4_col13 {
#   background-color: #8c0912;
# }
# #T_51c6a_row0_col14, #T_51c6a_row4_col14, #T_51c6a_row9_col12, #T_51c6a_row9_col13 {
#   background-color: #b61319;
# }
# #T_51c6a_row0_col15, #T_51c6a_row0_col16, #T_51c6a_row4_col15, #T_51c6a_row4_col16, #T_51c6a_row10_col11 {
#   background-color: #860811;
# }
# #T_51c6a_row0_col17, #T_51c6a_row3_col0, #T_51c6a_row3_col1, #T_51c6a_row4_col17 {
#   background-color: #840711;
# }
# #T_51c6a_row1_col0, #T_51c6a_row1_col1 {
#   background-color: #ac1117;
# }
# #T_51c6a_row1_col2 {
#   background-color: #f0402f;
# }
# #T_51c6a_row1_col3, #T_51c6a_row1_col4 {
#   background-color: #de2b25;
# }
# #T_51c6a_row1_col5 {
#   background-color: #e12d26;
# }
# #T_51c6a_row1_col6, #T_51c6a_row1_col7, #T_51c6a_row1_col8, #T_51c6a_row3_col3, #T_51c6a_row3_col4, #T_51c6a_row3_col5, #T_51c6a_row3_col9, #T_51c6a_row3_col10, #T_51c6a_row3_col11, #T_51c6a_row3_col12, #T_51c6a_row3_col13, #T_51c6a_row3_col14, #T_51c6a_row3_col15, #T_51c6a_row3_col16, #T_51c6a_row3_col17, #T_51c6a_row7_col0, #T_51c6a_row7_col1, #T_51c6a_row7_col2 {
#   background-color: #fb7c5c;
# }
# #T_51c6a_row1_col9, #T_51c6a_row1_col10 {
#   background-color: #bb141a;
# }
# #T_51c6a_row1_col11, #T_51c6a_row2_col11, #T_51c6a_row11_col2 {
#   background-color: #af1117;
# }
# #T_51c6a_row1_col12, #T_51c6a_row1_col13, #T_51c6a_row5_col6, #T_51c6a_row5_col7, #T_51c6a_row8_col12, #T_51c6a_row8_col13 {
#   background-color: #f5523a;
# }
# #T_51c6a_row1_col14 {
#   background-color: #ea362a;
# }
# #T_51c6a_row1_col15, #T_51c6a_row1_col16 {
#   background-color: #c5171c;
# }
# #T_51c6a_row1_col17, #T_51c6a_row10_col12, #T_51c6a_row10_col13 {
#   background-color: #b71319;
# }
# #T_51c6a_row2_col0, #T_51c6a_row2_col1 {
#   background-color: #dd2a25;
# }
# #T_51c6a_row2_col2 {
#   background-color: #f75c41;
# }
# #T_51c6a_row2_col3, #T_51c6a_row2_col4 {
#   background-color: #ce1a1e;
# }
# #T_51c6a_row2_col5 {
#   background-color: #b11218;
# }
# #T_51c6a_row2_col6, #T_51c6a_row2_col7, #T_51c6a_row6_col14 {
#   background-color: #b81419;
# }
# #T_51c6a_row2_col8 {
#   background-color: #f34935;
# }
# #T_51c6a_row2_col9, #T_51c6a_row2_col10, #T_51c6a_row11_col8 {
#   background-color: #a30f15;
# }
# #T_51c6a_row2_col12, #T_51c6a_row2_col13 {
#   background-color: #a81016;
# }
# #T_51c6a_row2_col14 {
#   background-color: #cb181d;
# }
# #T_51c6a_row2_col15, #T_51c6a_row2_col16, #T_51c6a_row6_col15, #T_51c6a_row6_col16, #T_51c6a_row8_col3, #T_51c6a_row8_col4 {
#   background-color: #6b010e;
# }
# #T_51c6a_row2_col17 {
#   background-color: #71020e;
# }
# #T_51c6a_row3_col2, #T_51c6a_row9_col6, #T_51c6a_row9_col7, #T_51c6a_row10_col6, #T_51c6a_row10_col7 {
#   background-color: #8a0812;
# }
# #T_51c6a_row3_col6, #T_51c6a_row3_col7, #T_51c6a_row8_col0, #T_51c6a_row8_col1 {
#   background-color: #fb7757;
# }
# #T_51c6a_row3_col8, #T_51c6a_row5_col14 {
#   background-color: #f5533b;
# }
# #T_51c6a_row5_col0, #T_51c6a_row5_col1, #T_51c6a_row5_col12, #T_51c6a_row5_col13, #T_51c6a_row7_col12, #T_51c6a_row7_col13 {
#   background-color: #fb6d4d;
# }
# #T_51c6a_row5_col2 {
#   background-color: #fb7151;
# }
# #T_51c6a_row5_col3, #T_51c6a_row5_col4, #T_51c6a_row5_col17, #T_51c6a_row10_col3, #T_51c6a_row10_col4, #T_51c6a_row11_col9, #T_51c6a_row11_col10 {
#   background-color: #79040f;
# }
# #T_51c6a_row5_col5, #T_51c6a_row6_col2 {
#   background-color: #940b13;
# }
# #T_51c6a_row5_col8 {
#   background-color: #fb7353;
# }
# #T_51c6a_row5_col9, #T_51c6a_row5_col10 {
#   background-color: #900a12;
# }
# #T_51c6a_row5_col11 {
#   background-color: #9f0e14;
# }
# #T_51c6a_row5_col15, #T_51c6a_row5_col16, #T_51c6a_row8_col9, #T_51c6a_row8_col10, #T_51c6a_row9_col17, #T_51c6a_row10_col17 {
#   background-color: #7a0510;
# }
# #T_51c6a_row6_col0, #T_51c6a_row6_col1 {
#   background-color: #d01d1f;
# }
# #T_51c6a_row6_col3, #T_51c6a_row6_col4 {
#   background-color: #f7593f;
# }
# #T_51c6a_row6_col5 {
#   background-color: #c4161c;
# }
# #T_51c6a_row6_col6, #T_51c6a_row6_col7, #T_51c6a_row9_col8, #T_51c6a_row11_col11 {
#   background-color: #7c0510;
# }
# #T_51c6a_row6_col8, #T_51c6a_row6_col9, #T_51c6a_row6_col10, #T_51c6a_row6_col11, #T_51c6a_row6_col17, #T_51c6a_row7_col3, #T_51c6a_row7_col4, #T_51c6a_row8_col15, #T_51c6a_row8_col16, #T_51c6a_row9_col5, #T_51c6a_row10_col2, #T_51c6a_row10_col5, #T_51c6a_row11_col0, #T_51c6a_row11_col1, #T_51c6a_row11_col6, #T_51c6a_row11_col7, #T_51c6a_row11_col12, #T_51c6a_row11_col13, #T_51c6a_row11_col14 {
#   background-color: #67000d;
# }
# #T_51c6a_row7_col5, #T_51c6a_row8_col5 {
#   background-color: #920a13;
# }
# #T_51c6a_row7_col6, #T_51c6a_row7_col7 {
#   background-color: #f96245;
# }
# #T_51c6a_row7_col8 {
#   background-color: #fb6e4e;
# }
# #T_51c6a_row7_col9, #T_51c6a_row7_col10, #T_51c6a_row7_col11, #T_51c6a_row9_col11 {
#   background-color: #880811;
# }
# #T_51c6a_row7_col14 {
#   background-color: #f44f39;
# }
# #T_51c6a_row7_col15, #T_51c6a_row7_col16, #T_51c6a_row7_col17, #T_51c6a_row11_col15, #T_51c6a_row11_col16, #T_51c6a_row11_col17 {
#   background-color: #73030f;
# }
# #T_51c6a_row8_col2 {
#   background-color: #fb7858;
# }
# #T_51c6a_row8_col6, #T_51c6a_row8_col7 {
#   background-color: #f44d38;
# }
# #T_51c6a_row8_col8 {
#   background-color: #f96346;
# }
# #T_51c6a_row8_col11, #T_51c6a_row9_col9, #T_51c6a_row9_col10, #T_51c6a_row11_col5 {
#   background-color: #820711;
# }
# #T_51c6a_row8_col14 {
#   background-color: #ec382b;
# }
# #T_51c6a_row8_col17 {
#   background-color: #69000d;
# }
# #T_51c6a_row9_col0, #T_51c6a_row9_col1 {
#   background-color: #e53228;
# }
# #T_51c6a_row9_col2 {
#   background-color: #6d010e;
# }
# #T_51c6a_row9_col3, #T_51c6a_row9_col4 {
#   background-color: #77040f;
# }
# #T_51c6a_row9_col14, #T_51c6a_row10_col14 {
#   background-color: #bd151a;
# }
# #T_51c6a_row9_col15, #T_51c6a_row9_col16, #T_51c6a_row10_col8, #T_51c6a_row10_col15, #T_51c6a_row10_col16 {
#   background-color: #800610;
# }
# #T_51c6a_row10_col0, #T_51c6a_row10_col1 {
#   background-color: #e43027;
# }
# #T_51c6a_row10_col9, #T_51c6a_row10_col10 {
#   background-color: #7e0610;
# }
# </style>
# <table id="T_51c6a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="6">TriviaQA, Bloomz3b</th>
#       <th class="col_heading level0 col6" colspan="6">XSUM, Bloomz3b</th>
#       <th class="col_heading level0 col12" colspan="6">MT, Bloomz3b</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" colspan="3">BARTScoreToken-rh</th>
#       <th class="col_heading level1 col3" colspan="3">LCS</th>
#       <th class="col_heading level1 col6" colspan="3">BARTScoreToken-rh</th>
#       <th class="col_heading level1 col9" colspan="3">LCS</th>
